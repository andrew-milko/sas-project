# %% [markdown]
# ___
# ___
# # `Код`

# %% [markdown]
# `Перезапуск`

# %%
# 1 - отправка в Kaggle
# 2 - локальный тест на 5-ти предпоследних неделях
# 3 - локальный тест на 5-ти последних неделях декабря 2018 года

submit = 1

# %% [markdown]
# ## `1. Загрузка данных`

# %%
import numpy as np
import pandas as pd

from copy import deepcopy
import itertools

from tqdm import tqdm
from matplotlib import pyplot as plt

product = pd.read_table('hse-dab-naf-22/PRODUCT.csv', sep=';')
location = pd.read_table('hse-dab-naf-22/LOCATION.csv', sep=';')

data = pd.read_table('hse-dab-naf-22/train.csv', sep=',')
sample_submission = pd.read_table('hse-dab-naf-22/sample_submission.csv', sep=',')

# %% [markdown]
# ___
# ## `2. Маски для разделение данных на обучающую и тестовую выборки`

# %%
data['period_dt'] = pd.to_datetime(data['period_dt'])

# %% [markdown]
# ### `2.1. Маска для сабмита в Kaggle`

# %%
def split_data_kaggle(data):
    ids_kaggle = np.array(sample_submission['id'].values)
    mask = data['id'].isin(ids_kaggle)
    
    train_mask = ~mask
    test_mask = mask
    
    return train_mask, test_mask

# %% [markdown]
# ### `2.2. Маска для предсказания дат [04.11.2019, 11.11.2019, 18.11.2019, 25.11.2019, 02.12.2019]`

# %%
def split_data_5_prev_weeks(data):
    mask_first = \
        (
            (data['period_dt'].dt.day == 4) | \
            (data['period_dt'].dt.day == 11) | \
            (data['period_dt'].dt.day == 18) | \
            (data['period_dt'].dt.day == 25)
        ) & \
        (data['period_dt'].dt.month == 11) & \
        (data['period_dt'].dt.year == 2019)

    mask_second = (data['period_dt'].dt.day == 2) & (data['period_dt'].dt.month == 12) & (data['period_dt'].dt.year == 2019)
    mask = mask_first | mask_second
    
    # Вырезаем все те даты, которые идут после упомянутых в скобках
    mask_remove = (data['period_dt'].dt.day > 2) & (data['period_dt'].dt.month == 12) & (data['period_dt'].dt.year == 2019)
    
    train_mask = ~mask_remove & ~mask
    test_mask = ~mask_remove & mask
    
    return train_mask, test_mask

# %% [markdown]
# ### `2.3. Маска для предсказания дат [03.12.2018, 10.12.2018, 17.12.2018, 24.12.2018, 31.12.2018]`

# %%
def split_data_5_last_weeks_of_2018(data):
    mask = \
        (
            (data['period_dt'].dt.day == 3) | \
            (data['period_dt'].dt.day == 10) | \
            (data['period_dt'].dt.day == 17) | \
            (data['period_dt'].dt.day == 24) | \
            (data['period_dt'].dt.day == 31)
        ) & \
        (data['period_dt'].dt.month == 12) & \
        (data['period_dt'].dt.year == 2018)
    
    # Вырезаем все те даты, которые идут после упомянутых в скобках
    mask_remove = (data['period_dt'].dt.year == 2019)

    train_mask = ~mask_remove & ~mask
    test_mask = ~mask_remove & mask
    
    return train_mask, test_mask

# %% [markdown]
# ___
# ## `3. Предобработка данных`

# %%
features_cat = ['period_dt', 'location_id', 'product_id', 'PROMO1_FLAG', 'PROMO2_FLAG', 'AUTORIZATION_FLAG']
features_num = ['PRICE_REGULAR', 'PRICE_AFTER_DISC', 'NUM_CONSULTANT']
target = 'demand'

# %% [markdown]
# ### `3.1. Заполнение пропусков в некоторых признаках`

# %%
def fill_nans(data):
    mask = pd.isna(data['PROMO1_FLAG'])
    data.loc[mask, 'PROMO1_FLAG'] = 0.0

    mask = pd.isna(data['PROMO2_FLAG'])
    data.loc[mask, 'PROMO2_FLAG'] = 0.0

    mask = pd.isna(data['PRICE_REGULAR'])
    data.loc[mask, 'PRICE_REGULAR'] = data['PRICE_REGULAR'].mean()

    mask = pd.isna(data['PRICE_AFTER_DISC'])
    data.loc[mask, 'PRICE_AFTER_DISC'] = data['PRICE_AFTER_DISC'].mean()

    mask = pd.isna(data['NUM_CONSULTANT'])
    data.loc[mask, 'NUM_CONSULTANT'] = 0.0

    mask = pd.isna(data['AUTORIZATION_FLAG'])
    data.loc[mask, 'AUTORIZATION_FLAG'] = 1.0
    
    return data

# %% [markdown]
# ### `3.2. Создание новых признаков в виде дня, месяца и года`

# %%
def day_month_year_features(data, features_cat, features_num):
    data['period_dt'] = pd.to_datetime(data['period_dt'])
    
    data['day'] = data['period_dt'].dt.day
    data['month'] = data['period_dt'].dt.month
    data['year'] = data['period_dt'].dt.year
    
    features_num += ['day', 'month', 'year']
    
    return data

# %% [markdown]
# ### `3.3. Удаление признаков`

# %%
def delete_feature(data, features_cat, features_num, feature_names):
    for feature_name in feature_names:
        data = data.drop(columns=[feature_name])

        if feature_name in features_num:
            features_num.remove(feature_name)

        if feature_name in features_cat:
            features_cat.remove(feature_name)
        
    return data

# %% [markdown]
# ### `3.4. Таблица PRODUCT`

# %%
def product_table_features(data, features_cat, features_num, product, is_useful_columns=True):
    table = product.copy()

    mask = ~pd.isna(data['product_id'])
    elements_unique = data[mask]['product_id'].unique()

    table_sliced = table.loc[table['PRODUCT_RK'].isin(elements_unique)].copy()    
    
    useful_columns = []
    if is_useful_columns:
        for col in table_sliced:
            #---------------------------------------------------------------#
            unique_count = table_sliced[col].unique().size
    
            if (unique_count > 1) and (unique_count != elements_unique.size):
                if ('RK' in col) or ('ATTRIB' in col):
                    useful_columns += [col]
            #---------------------------------------------------------------#

        table_sliced = table_sliced[['PRODUCT_RK'] + useful_columns]

    features_count = table_sliced.shape[1] - 1
    features_names = table_sliced.keys()[1:]

    data[features_names] = ''

    for elem in tqdm(elements_unique):
        mask_1 = (table_sliced['PRODUCT_RK'] == elem)
        mask_2 = (data['product_id'] == elem)
        data.loc[mask_2, features_names] = table_sliced[features_names][mask_1].values

    features_cat += list(features_names)

    return data

# %% [markdown]
# ### `3.5. Таблица LOCATION`

# %%
def location_table_features(data, features_cat, features_num, location, is_useful_columns=True):
    table = location.copy()

    mask = ~pd.isna(data['location_id'])
    elements_unique = data[mask]['location_id'].unique()

    table_sliced = table.loc[table['STORE_LOCATION_RK'].isin(elements_unique)].copy()    
    
    useful_columns = []
    if is_useful_columns:
        for col in table_sliced:
            #---------------------------------------------------------------#
            unique_count = table_sliced[col].unique().size
    
            if (unique_count > 1) and (unique_count != elements_unique.size):
                if ('RK4' in col) or ('ATTRIB2' in col) or ('ATTRIB3' in col) or \
                ('ATTRIB4' in col) or ('ATTRIB8' in col) or \
                ('ATTRIB9' in col) or ('ATTRIB10' in col):
                    useful_columns += [col]
            #---------------------------------------------------------------#

        table_sliced = table_sliced[['STORE_LOCATION_RK'] + useful_columns]

    features_count = table_sliced.shape[1] - 1
    features_names = table_sliced.keys()[1:]

    data[features_names] = ''

    for elem in tqdm(elements_unique):
        mask_1 = (table_sliced['STORE_LOCATION_RK'] == elem)
        mask_2 = (data['location_id'] == elem)
        data.loc[mask_2, features_names] = table_sliced[features_names][mask_1].values

    features_cat += list(features_names)

    return data

# %% [markdown]
# ### `3.6.  lag-features`

# %%
def lagged_features(
    data,
    cat,
    num,
    target_var = 'demand',
    org_id_columns = ['product_id', 'location_id'],
    all_id_columns = ['product_id', 'location_id', 'period_dt'],
    lags = [5],
    windows = [5],
    aggregation_methods = {'mean', 'median', 'var', 'std'},
    filters = None):
    
    out_df = deepcopy(data)
    
    have_filters = True
    
    if filters is None:
        have_filters = False
        filters = {'':{''}}
        
    keys, values = zip(*filters.items())
    
    #_____________________________#
    
    for bundle in itertools.product(*values):
        condition = ''
        
        if have_filters:
            condition = ' & '.join([keys[i] + filters[keys[i]][bundle[i]] for i in range(len(keys))])
            
        name =  '_'.join([bundle[i] for i in range(len(keys))])
        
        if len(condition) > 0:
            _idx = data.eval(condition)
        else:
            _idx = data.index >= 0

        if len(data[_idx]) > 0:

            #_______________#
            
            for w in tqdm(windows):

                lf_df = data[_idx].set_index(all_id_columns)[target_var].\
                    groupby(level=org_id_columns).\
                        apply(lambda x: x.rolling(window=w, min_periods = 1).\
                            agg(aggregation_methods))

                #____________#
                
                for l in tqdm(lags):

                    if have_filters:
                        new_names = \
                            {x: "lag{0}_wdw{1}_{2}_{3}".format(l, w, x, name) for x in lf_df.columns }
                    else:
                        new_names = \
                            {x: "lag{0}_wdw{1}_{2}".format(l, w, x) for x in lf_df.columns }

                    out_df = \
                        pd.merge(
                            out_df,
                            lf_df.shift(l).reset_index().rename(columns = new_names),
                            how='left',
                            on=all_id_columns
                        )
    #___________#
    
    new_numeric_features = []

    for col in out_df.columns:
        if col[:3] == 'lag':
            new_numeric_features += [col]
            
    num += new_numeric_features
    
    assert (out_df[num + cat].shape[1] + 1) == (out_df.shape[1])

    return out_df

# %% [markdown]
# ___
# ## `4. Разделение на обучающую и тестовую выборки`

# %%
train_mask_kaggle, test_mask_kaggle = split_data_kaggle(data)
train_mask_5_prev_weeks, test_mask_5_prev_weeks = split_data_5_prev_weeks(data)
train_mask_5_last_weeks_of_2018, test_mask_5_last_weeks_of_2018 = split_data_5_last_weeks_of_2018(data)

# %% [markdown]
# `Перезапуск`

# %%
if submit == 1:
    train_mask, test_mask = train_mask_kaggle, test_mask_kaggle
elif submit == 2:
    train_mask, test_mask = train_mask_5_prev_weeks, test_mask_5_prev_weeks
elif submit == 3:
    train_mask, test_mask = train_mask_5_last_weeks_of_2018, test_mask_5_last_weeks_of_2018
else:
    print('clown')

# %% [markdown]
# ___
# ### `*. Формируем данные`

# %% [markdown]
# `Удаляем 'id'`

# %%
data = delete_feature(data, features_cat, features_num, ['id'])

# %% [markdown]
# `Формируем lag-features`

# %%
#mask_location = ~pd.isna(data['location_id'])
#mask_product = ~pd.isna(data['product_id'])

# %%
#data = data[mask_location & mask_product]

# %%
#data = \
#    lagged_features(
#        data,
#        features_cat,
#        features_num,
#        lags = [0, 26, 52, 78, 104, 130],
#        windows = [12, 26, 52],
#        filters = None)

# %% [markdown]
# `Добавляем новые признаки в виде дня, месяца и года`

# %%
data = day_month_year_features(data, features_cat, features_num)

# %% [markdown]
# `Удаляем признак 'period_dt'`

# %%
data = delete_feature(data, features_cat, features_num, ['period_dt'])

# %% [markdown]
# `Заполняем пропуски`

# %%
data = fill_nans(data)

# %% [markdown]
# `Добавление признаков из таблицы LOCATION`

# %%
#data = location_table_features(data, features_cat, features_num, location, is_useful_columns=True)

# %% [markdown]
# `Добавление признаков из таблицы PRODUCT`

# %%
data = product_table_features(data, features_cat, features_num, product, is_useful_columns=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2140/2140 [22:09<00:00,  1.61it/s]

# %% [markdown]
# ___
# ### `*. Разделение`

# %% [markdown]
# `Перезапуск`

# %%
#train = data[train_mask[mask_location & mask_product]].copy()
#test = data[test_mask[mask_location & mask_product]].copy()

train = data[train_mask].copy()
test = data[test_mask].copy()

# %% [markdown]
# `Обрежем тестовую выборку так, чтобы ею можно было бы валидировать результаты. Имеем смысл только для локального тестирования.`

# %%
if submit == 2 or submit == 3:
    test = test[~pd.isna(test['demand'])]

# %%
test.head()
# Out:
#        location_id  product_id  demand  PROMO1_FLAG  PROMO2_FLAG  \
# 10          1162.0     22939.0     NaN          0.0          0.0
# 7781        1162.0     23162.0     NaN          0.0          0.0
# 8574        1162.0     23163.0     NaN          0.0          0.0
# 14686        798.0     23632.0     NaN          0.0          0.0
# 14797       1347.0     23633.0     NaN          0.0          0.0
#
#        PRICE_REGULAR  PRICE_AFTER_DISC  NUM_CONSULTANT  AUTORIZATION_FLAG  \
# 10            3649.0           2189.40             0.0                1.0
# 7781          3799.0           2279.40             0.0                1.0
# 8574          3799.0           2849.25             0.0                1.0
# 14686         3999.0           2399.40             0.0                1.0
# 14797         3999.0           2999.25             0.0                1.0
#
#        day  ...          PRODUCT_ATTRIB10_hashing  \
# 10      30  ...  469EDF2953F2FE3282C01BB4DA50D3DE
# 7781    30  ...  469EDF2953F2FE3282C01BB4DA50D3DE
# 8574    16  ...  469EDF2953F2FE3282C01BB4DA50D3DE
# 14686   23  ...  469EDF2953F2FE3282C01BB4DA50D3DE
# 14797   30  ...  469EDF2953F2FE3282C01BB4DA50D3DE
#
#                PRODUCT_ATTRIB12_hashing          PRODUCT_ATTRIB13_hashing  \
# 10     469EDF2953F2FE3282C01BB4DA50D3DE  082C6C1C596475C2DBA0649E9C3EF4CC
# 7781   469EDF2953F2FE3282C01BB4DA50D3DE  082C6C1C596475C2DBA0649E9C3EF4CC
# 8574   469EDF2953F2FE3282C01BB4DA50D3DE  082C6C1C596475C2DBA0649E9C3EF4CC
# 14686  469EDF2953F2FE3282C01BB4DA50D3DE  082C6C1C596475C2DBA0649E9C3EF4CC
# 14797  469EDF2953F2FE3282C01BB4DA50D3DE  082C6C1C596475C2DBA0649E9C3EF4CC
#
#                PRODUCT_ATTRIB15_hashing          PRODUCT_ATTRIB16_hashing  \
# 10     B2581C791DBB8894BFDCFB66B60A17ED  ABA19183688552984DCF8FE467B5D008
# 7781   B2581C791DBB8894BFDCFB66B60A17ED  ABA19183688552984DCF8FE467B5D008
# 8574   B2581C791DBB8894BFDCFB66B60A17ED  ABA19183688552984DCF8FE467B5D008
# 14686  B2581C791DBB8894BFDCFB66B60A17ED  ABA19183688552984DCF8FE467B5D008
# 14797  B2581C791DBB8894BFDCFB66B60A17ED  ABA19183688552984DCF8FE467B5D008
#
#                PRODUCT_ATTRIB18_hashing          PRODUCT_ATTRIB21_hashing  \
# 10     0493DC077A6D8708F386CC48B88E1EF3  8CE9C7F761F769882B2C8D05B153760B
# 7781   6022A682C75D6B2834935B68C518BC04  8CE9C7F761F769882B2C8D05B153760B
# 8574   6022A682C75D6B2834935B68C518BC04  8CE9C7F761F769882B2C8D05B153760B
# 14686  0493DC077A6D8708F386CC48B88E1EF3  D165570588A15A2EB9A9E24D2E8E2FBD
# 14797  0493DC077A6D8708F386CC48B88E1EF3  8CE9C7F761F769882B2C8D05B153760B
#
#                PRODUCT_ATTRIB22_hashing          PRODUCT_ATTRIB23_hashing  \
# 10     EA4B7C50D9AEF0EA71897172C02442B8  082C6C1C596475C2DBA0649E9C3EF4CC
# 7781   EA4B7C50D9AEF0EA71897172C02442B8  082C6C1C596475C2DBA0649E9C3EF4CC
# 8574   EA4B7C50D9AEF0EA71897172C02442B8  082C6C1C596475C2DBA0649E9C3EF4CC
# 14686  EA4B7C50D9AEF0EA71897172C02442B8  082C6C1C596475C2DBA0649E9C3EF4CC
# 14797  EA4B7C50D9AEF0EA71897172C02442B8  082C6C1C596475C2DBA0649E9C3EF4CC
#
#                PRODUCT_ATTRIB25_hashing
# 10     E054D49EAC1E947B5CB0EE77952C5F9E
# 7781   8CF5176515BEEC570D4FB22350A55641
# 8574   8CF5176515BEEC570D4FB22350A55641
# 14686  8CF5176515BEEC570D4FB22350A55641
# 14797  8CF5176515BEEC570D4FB22350A55641
#
# [5 rows x 31 columns]

# %% [markdown]
# ` Обучающую выборку будем иметь в двух видах:`
# - `train_full - это весь train, в котором не факт, что везде известна целевая переменная`
# - `train - это срез исходного train'а по объектам с известными целевыми переменными`

# %%
train_full = train.copy()
train = train[~pd.isna(train['demand'])].copy()

# %%
train_full.shape, train.shape, test.shape
# Out:
# ((2332510, 31), (274471, 31), (593, 31))

# %% [markdown]
# ___
# ## `5. Запуск модели`

# %%
x_train = train.drop(columns=['demand']).copy()
y_train = train['demand'].copy()

x_test = test.drop(columns=['demand']).copy()
y_test = test['demand'].copy()

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((274471, 30), (274471,), (593, 30), (593,))

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %%
from sklearn.metrics import mean_absolute_error

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
import xgboost as xgb
import lightgbm as ltb

# %%
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error

# %%
column_transformer = ColumnTransformer([
        ('scaler', StandardScaler(), features_num),
        ('ohe', OneHotEncoder(), features_cat)
    ], remainder='passthrough')

column_transformer.fit(pd.concat([x_train, x_test], axis=0))
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('scaler', StandardScaler(),
#                                  ['PRICE_REGULAR', 'PRICE_AFTER_DISC',
#                                   'NUM_CONSULTANT', 'day', 'month', 'year']),
#                                 ('ohe', OneHotEncoder(),
#                                  ['location_id', 'product_id', 'PROMO1_FLAG',
#                                   'PROMO2_FLAG', 'AUTORIZATION_FLAG',
#                                   'PRODUCT_LVL_RK6', 'PRODUCT_ATTRIB2_hashing',
#                                   'PRODUCT_ATTRIB3_hashing',
#                                   'PRODUCT_ATTRIB4_hashi...
#                                   'PRODUCT_ATTRIB7_hashing',
#                                   'PRODUCT_ATTRIB8_hashing',
#                                   'PRODUCT_ATTRIB9_hashing',
#                                   'PRODUCT_ATTRIB10_hashing',
#                                   'PRODUCT_ATTRIB12_hashing',
#                                   'PRODUCT_ATTRIB13_hashing',
#                                   'PRODUCT_ATTRIB15_hashing',
#                                   'PRODUCT_ATTRIB16_hashing',
#                                   'PRODUCT_ATTRIB18_hashing',
#                                   'PRODUCT_ATTRIB21_hashing',
#                                   'PRODUCT_ATTRIB22_hashing',
#                                   'PRODUCT_ATTRIB23_hashing',
#                                   'PRODUCT_ATTRIB25_hashing'])])

# %% [markdown]
# ___

# %%
y_scaler = StandardScaler()
y_scaler.fit(np.array(y_train).reshape(-1, 1))
# Out:
# StandardScaler()

# %%
y_train_scaled = y_scaler.transform(np.array(y_train).reshape(-1, 1))

# %%
model = CatBoostRegressor(
    verbose=True,
    depth=5,
    learning_rate=0.099,
    l2_leaf_reg=5
)

model.fit(column_transformer.transform(x_train), y_train)
# Out:
# 0:	learn: 0.7128356	total: 30.3ms	remaining: 30.2s
# 1:	learn: 0.7019605	total: 60.1ms	remaining: 30s
# 2:	learn: 0.6930821	total: 91.2ms	remaining: 30.3s
# 3:	learn: 0.6848165	total: 119ms	remaining: 29.7s
# 4:	learn: 0.6778952	total: 151ms	remaining: 30s
# 5:	learn: 0.6721427	total: 181ms	remaining: 29.9s
# 6:	learn: 0.6667531	total: 210ms	remaining: 29.8s
# 7:	learn: 0.6620622	total: 237ms	remaining: 29.3s
# 8:	learn: 0.6579555	total: 268ms	remaining: 29.5s
# 9:	learn: 0.6544402	total: 296ms	remaining: 29.3s
# 10:	learn: 0.6509436	total: 324ms	remaining: 29.2s
# 11:	learn: 0.6477340	total: 350ms	remaining: 28.8s
# 12:	learn: 0.6452354	total: 377ms	remaining: 28.6s
# 13:	learn: 0.6428369	total: 403ms	remaining: 28.4s
# 14:	learn: 0.6405069	total: 432ms	remaining: 28.3s
# 15:	learn: 0.6383383	total: 457ms	remaining: 28.1s
# 16:	learn: 0.6359942	total: 495ms	remaining: 28.6s
# 17:	learn: 0.6344909	total: 528ms	remaining: 28.8s
# 18:	learn: 0.6328019	total: 556ms	remaining: 28.7s
# 19:	learn: 0.6311662	total: 586ms	remaining: 28.7s
# 20:	learn: 0.6294842	total: 621ms	remaining: 28.9s
# 21:	learn: 0.6283450	total: 645ms	remaining: 28.7s
# 22:	learn: 0.6267722	total: 676ms	remaining: 28.7s
# 23:	learn: 0.6256303	total: 707ms	remaining: 28.7s
# 24:	learn: 0.6240891	total: 742ms	remaining: 28.9s
# 25:	learn: 0.6229007	total: 770ms	remaining: 28.8s
# 26:	learn: 0.6217921	total: 805ms	remaining: 29s
# 27:	learn: 0.6208743	total: 833ms	remaining: 28.9s
# 28:	learn: 0.6198392	total: 862ms	remaining: 28.9s
# 29:	learn: 0.6188074	total: 890ms	remaining: 28.8s
# 30:	learn: 0.6180414	total: 918ms	remaining: 28.7s
# 31:	learn: 0.6171764	total: 943ms	remaining: 28.5s
# 32:	learn: 0.6163282	total: 968ms	remaining: 28.4s
# 33:	learn: 0.6153988	total: 998ms	remaining: 28.3s
# 34:	learn: 0.6146082	total: 1.03s	remaining: 28.3s
# 35:	learn: 0.6138073	total: 1.05s	remaining: 28.2s
# 36:	learn: 0.6132345	total: 1.07s	remaining: 28s
# 37:	learn: 0.6124932	total: 1.1s	remaining: 28s
# 38:	learn: 0.6114877	total: 1.13s	remaining: 28s
# 39:	learn: 0.6107152	total: 1.16s	remaining: 27.9s
# 40:	learn: 0.6097777	total: 1.19s	remaining: 27.9s
# 41:	learn: 0.6091651	total: 1.22s	remaining: 27.9s
# 42:	learn: 0.6084855	total: 1.25s	remaining: 27.8s
# 43:	learn: 0.6079661	total: 1.27s	remaining: 27.7s
# 44:	learn: 0.6072785	total: 1.3s	remaining: 27.7s
# 45:	learn: 0.6070306	total: 1.32s	remaining: 27.5s
# 46:	learn: 0.6064460	total: 1.36s	remaining: 27.5s
# 47:	learn: 0.6059808	total: 1.38s	remaining: 27.4s
# 48:	learn: 0.6055084	total: 1.41s	remaining: 27.4s
# 49:	learn: 0.6045800	total: 1.44s	remaining: 27.3s
# 50:	learn: 0.6041550	total: 1.46s	remaining: 27.2s
# 51:	learn: 0.6036330	total: 1.49s	remaining: 27.1s
# 52:	learn: 0.6030752	total: 1.52s	remaining: 27.1s
# 53:	learn: 0.6025081	total: 1.54s	remaining: 27s
# 54:	learn: 0.6020990	total: 1.57s	remaining: 27s
# 55:	learn: 0.6016974	total: 1.6s	remaining: 26.9s
# 56:	learn: 0.6012971	total: 1.62s	remaining: 26.9s
# 57:	learn: 0.6005721	total: 1.66s	remaining: 26.9s
# 58:	learn: 0.6002058	total: 1.69s	remaining: 26.9s
# 59:	learn: 0.5997738	total: 1.71s	remaining: 26.8s
# 60:	learn: 0.5993799	total: 1.74s	remaining: 26.8s
# 61:	learn: 0.5987859	total: 1.77s	remaining: 26.7s
# 62:	learn: 0.5982808	total: 1.79s	remaining: 26.7s
# 63:	learn: 0.5976995	total: 1.82s	remaining: 26.7s
# 64:	learn: 0.5971511	total: 1.85s	remaining: 26.6s
# 65:	learn: 0.5966082	total: 1.88s	remaining: 26.6s
# 66:	learn: 0.5963117	total: 1.91s	remaining: 26.5s
# 67:	learn: 0.5956812	total: 1.93s	remaining: 26.5s
# 68:	learn: 0.5954077	total: 1.96s	remaining: 26.4s
# 69:	learn: 0.5951042	total: 1.98s	remaining: 26.3s
# 70:	learn: 0.5947511	total: 2.01s	remaining: 26.3s
# 71:	learn: 0.5942871	total: 2.04s	remaining: 26.3s
# 72:	learn: 0.5939531	total: 2.06s	remaining: 26.2s
# 73:	learn: 0.5933545	total: 2.09s	remaining: 26.2s
# 74:	learn: 0.5931890	total: 2.12s	remaining: 26.1s
# 75:	learn: 0.5929873	total: 2.15s	remaining: 26.1s
# 76:	learn: 0.5925917	total: 2.18s	remaining: 26.1s
# 77:	learn: 0.5922893	total: 2.2s	remaining: 26s
# 78:	learn: 0.5919354	total: 2.23s	remaining: 26.1s
# 79:	learn: 0.5915552	total: 2.26s	remaining: 26s
# 80:	learn: 0.5912681	total: 2.29s	remaining: 26s
# 81:	learn: 0.5906424	total: 2.33s	remaining: 26.1s
# 82:	learn: 0.5903965	total: 2.36s	remaining: 26.1s
# 83:	learn: 0.5902065	total: 2.39s	remaining: 26.1s
# 84:	learn: 0.5900112	total: 2.42s	remaining: 26.1s
# 85:	learn: 0.5896453	total: 2.45s	remaining: 26.1s
# 86:	learn: 0.5893626	total: 2.49s	remaining: 26.1s
# 87:	learn: 0.5889727	total: 2.52s	remaining: 26.1s
# 88:	learn: 0.5884807	total: 2.55s	remaining: 26.1s
# 89:	learn: 0.5881436	total: 2.58s	remaining: 26.1s
# 90:	learn: 0.5879634	total: 2.6s	remaining: 26s
# 91:	learn: 0.5877583	total: 2.63s	remaining: 25.9s
# 92:	learn: 0.5875374	total: 2.65s	remaining: 25.9s
# 93:	learn: 0.5872952	total: 2.68s	remaining: 25.8s
# 94:	learn: 0.5870746	total: 2.71s	remaining: 25.8s
# 95:	learn: 0.5867632	total: 2.73s	remaining: 25.7s
# 96:	learn: 0.5864650	total: 2.76s	remaining: 25.7s
# 97:	learn: 0.5862607	total: 2.79s	remaining: 25.6s
# 98:	learn: 0.5859592	total: 2.81s	remaining: 25.6s
# 99:	learn: 0.5855891	total: 2.84s	remaining: 25.6s
# 100:	learn: 0.5853210	total: 2.87s	remaining: 25.5s
# 101:	learn: 0.5851336	total: 2.89s	remaining: 25.5s
# 102:	learn: 0.5848957	total: 2.92s	remaining: 25.4s
# 103:	learn: 0.5846289	total: 2.95s	remaining: 25.4s
# 104:	learn: 0.5839864	total: 2.98s	remaining: 25.4s
# 105:	learn: 0.5838248	total: 3s	remaining: 25.3s
# 106:	learn: 0.5833008	total: 3.04s	remaining: 25.3s
# 107:	learn: 0.5831565	total: 3.06s	remaining: 25.3s
# 108:	learn: 0.5830281	total: 3.09s	remaining: 25.3s
# 109:	learn: 0.5828260	total: 3.12s	remaining: 25.2s
# 110:	learn: 0.5825518	total: 3.15s	remaining: 25.2s
# 111:	learn: 0.5822583	total: 3.17s	remaining: 25.2s
# 112:	learn: 0.5820329	total: 3.2s	remaining: 25.1s
# 113:	learn: 0.5818340	total: 3.23s	remaining: 25.1s
# 114:	learn: 0.5815888	total: 3.25s	remaining: 25.1s
# 115:	learn: 0.5813869	total: 3.28s	remaining: 25s
# 116:	learn: 0.5812003	total: 3.31s	remaining: 25s
# 117:	learn: 0.5809031	total: 3.33s	remaining: 24.9s
# 118:	learn: 0.5806889	total: 3.36s	remaining: 24.9s
# 119:	learn: 0.5805351	total: 3.39s	remaining: 24.9s
# 120:	learn: 0.5802774	total: 3.42s	remaining: 24.8s
# 121:	learn: 0.5801120	total: 3.44s	remaining: 24.8s
# 122:	learn: 0.5796677	total: 3.48s	remaining: 24.8s
# 123:	learn: 0.5795688	total: 3.51s	remaining: 24.8s
# 124:	learn: 0.5793634	total: 3.54s	remaining: 24.8s
# 125:	learn: 0.5791238	total: 3.57s	remaining: 24.8s
# 126:	learn: 0.5788025	total: 3.6s	remaining: 24.8s
# 127:	learn: 0.5784991	total: 3.63s	remaining: 24.7s
# 128:	learn: 0.5782834	total: 3.65s	remaining: 24.7s
# 129:	learn: 0.5780933	total: 3.68s	remaining: 24.6s
# 130:	learn: 0.5779397	total: 3.7s	remaining: 24.6s
# 131:	learn: 0.5774523	total: 3.73s	remaining: 24.6s
# 132:	learn: 0.5771854	total: 3.77s	remaining: 24.5s
# 133:	learn: 0.5767291	total: 3.79s	remaining: 24.5s
# 134:	learn: 0.5765300	total: 3.82s	remaining: 24.5s
# 135:	learn: 0.5764049	total: 3.85s	remaining: 24.4s
# 136:	learn: 0.5762250	total: 3.87s	remaining: 24.4s
# 137:	learn: 0.5760273	total: 3.9s	remaining: 24.4s
# 138:	learn: 0.5757904	total: 3.93s	remaining: 24.4s
# 139:	learn: 0.5752813	total: 3.96s	remaining: 24.4s
# 140:	learn: 0.5751040	total: 4s	remaining: 24.3s
# 141:	learn: 0.5749181	total: 4.02s	remaining: 24.3s
# 142:	learn: 0.5747956	total: 4.05s	remaining: 24.3s
# 143:	learn: 0.5745953	total: 4.07s	remaining: 24.2s
# 144:	learn: 0.5744701	total: 4.1s	remaining: 24.2s
# 145:	learn: 0.5743407	total: 4.12s	remaining: 24.1s
# 146:	learn: 0.5742347	total: 4.15s	remaining: 24.1s
# 147:	learn: 0.5739849	total: 4.17s	remaining: 24s
# 148:	learn: 0.5737899	total: 4.2s	remaining: 24s
# 149:	learn: 0.5735516	total: 4.23s	remaining: 24s
# 150:	learn: 0.5733306	total: 4.26s	remaining: 23.9s
# 151:	learn: 0.5731377	total: 4.29s	remaining: 23.9s
# 152:	learn: 0.5727993	total: 4.31s	remaining: 23.9s
# 153:	learn: 0.5725738	total: 4.34s	remaining: 23.8s
# 154:	learn: 0.5723663	total: 4.36s	remaining: 23.8s
# 155:	learn: 0.5721087	total: 4.39s	remaining: 23.8s
# 156:	learn: 0.5719101	total: 4.42s	remaining: 23.7s
# 157:	learn: 0.5717549	total: 4.45s	remaining: 23.7s
# 158:	learn: 0.5714710	total: 4.47s	remaining: 23.7s
# 159:	learn: 0.5712998	total: 4.5s	remaining: 23.6s
# 160:	learn: 0.5711896	total: 4.52s	remaining: 23.6s
# 161:	learn: 0.5710123	total: 4.55s	remaining: 23.5s
# 162:	learn: 0.5708365	total: 4.57s	remaining: 23.5s
# 163:	learn: 0.5706575	total: 4.6s	remaining: 23.5s
# 164:	learn: 0.5705240	total: 4.63s	remaining: 23.4s
# 165:	learn: 0.5702950	total: 4.69s	remaining: 23.6s
# 166:	learn: 0.5700952	total: 4.72s	remaining: 23.5s
# 167:	learn: 0.5698992	total: 4.74s	remaining: 23.5s
# 168:	learn: 0.5697453	total: 4.77s	remaining: 23.5s
# 169:	learn: 0.5695413	total: 4.8s	remaining: 23.4s
# 170:	learn: 0.5692386	total: 4.82s	remaining: 23.4s
# 171:	learn: 0.5690730	total: 4.85s	remaining: 23.3s
# 172:	learn: 0.5688869	total: 4.87s	remaining: 23.3s
# 173:	learn: 0.5687221	total: 4.9s	remaining: 23.3s
# 174:	learn: 0.5685655	total: 4.93s	remaining: 23.2s
# 175:	learn: 0.5684117	total: 4.96s	remaining: 23.2s
# 176:	learn: 0.5682688	total: 4.98s	remaining: 23.2s
# 177:	learn: 0.5681272	total: 5.01s	remaining: 23.1s
# 178:	learn: 0.5679907	total: 5.04s	remaining: 23.1s
# 179:	learn: 0.5677949	total: 5.07s	remaining: 23.1s
# 180:	learn: 0.5676230	total: 5.09s	remaining: 23s
# 181:	learn: 0.5674079	total: 5.12s	remaining: 23s
# 182:	learn: 0.5672570	total: 5.14s	remaining: 23s
# 183:	learn: 0.5671688	total: 5.17s	remaining: 22.9s
# 184:	learn: 0.5670873	total: 5.19s	remaining: 22.9s
# 185:	learn: 0.5668832	total: 5.22s	remaining: 22.8s
# 186:	learn: 0.5667836	total: 5.24s	remaining: 22.8s
# 187:	learn: 0.5666216	total: 5.27s	remaining: 22.8s
# 188:	learn: 0.5664146	total: 5.3s	remaining: 22.7s
# 189:	learn: 0.5662491	total: 5.33s	remaining: 22.7s
# 190:	learn: 0.5660722	total: 5.36s	remaining: 22.7s
# 191:	learn: 0.5659663	total: 5.39s	remaining: 22.7s
# 192:	learn: 0.5659323	total: 5.41s	remaining: 22.6s
# 193:	learn: 0.5658239	total: 5.43s	remaining: 22.6s
# 194:	learn: 0.5656203	total: 5.46s	remaining: 22.6s
# 195:	learn: 0.5654237	total: 5.49s	remaining: 22.5s
# 196:	learn: 0.5652391	total: 5.52s	remaining: 22.5s
# 197:	learn: 0.5652073	total: 5.54s	remaining: 22.5s
# 198:	learn: 0.5648571	total: 5.58s	remaining: 22.4s
# 199:	learn: 0.5645856	total: 5.6s	remaining: 22.4s
# 200:	learn: 0.5643695	total: 5.63s	remaining: 22.4s
# 201:	learn: 0.5641615	total: 5.66s	remaining: 22.4s
# 202:	learn: 0.5640556	total: 5.68s	remaining: 22.3s
# 203:	learn: 0.5640268	total: 5.71s	remaining: 22.3s
# 204:	learn: 0.5639008	total: 5.74s	remaining: 22.2s
# 205:	learn: 0.5637187	total: 5.76s	remaining: 22.2s
# 206:	learn: 0.5636253	total: 5.79s	remaining: 22.2s
# 207:	learn: 0.5634871	total: 5.82s	remaining: 22.1s
# 208:	learn: 0.5633656	total: 5.84s	remaining: 22.1s
# 209:	learn: 0.5632090	total: 5.87s	remaining: 22.1s
# 210:	learn: 0.5631170	total: 5.9s	remaining: 22.1s
# 211:	learn: 0.5630238	total: 5.92s	remaining: 22s
# 212:	learn: 0.5629470	total: 5.95s	remaining: 22s
# 213:	learn: 0.5627898	total: 5.97s	remaining: 21.9s
# 214:	learn: 0.5627611	total: 6s	remaining: 21.9s
# 215:	learn: 0.5626137	total: 6.02s	remaining: 21.9s
# 216:	learn: 0.5622066	total: 6.05s	remaining: 21.8s
# 217:	learn: 0.5620753	total: 6.08s	remaining: 21.8s
# 218:	learn: 0.5619867	total: 6.11s	remaining: 21.8s
# 219:	learn: 0.5618183	total: 6.15s	remaining: 21.8s
# 220:	learn: 0.5616958	total: 6.18s	remaining: 21.8s
# 221:	learn: 0.5616697	total: 6.2s	remaining: 21.7s
# 222:	learn: 0.5615350	total: 6.24s	remaining: 21.7s
# 223:	learn: 0.5613936	total: 6.26s	remaining: 21.7s
# 224:	learn: 0.5612567	total: 6.29s	remaining: 21.7s
# 225:	learn: 0.5611340	total: 6.33s	remaining: 21.7s
# 226:	learn: 0.5610512	total: 6.35s	remaining: 21.6s
# 227:	learn: 0.5609211	total: 6.38s	remaining: 21.6s
# 228:	learn: 0.5608011	total: 6.41s	remaining: 21.6s
# 229:	learn: 0.5606581	total: 6.44s	remaining: 21.6s
# 230:	learn: 0.5605598	total: 6.46s	remaining: 21.5s
# 231:	learn: 0.5604401	total: 6.49s	remaining: 21.5s
# 232:	learn: 0.5602765	total: 6.52s	remaining: 21.5s
# 233:	learn: 0.5601974	total: 6.55s	remaining: 21.4s
# 234:	learn: 0.5600835	total: 6.58s	remaining: 21.4s
# 235:	learn: 0.5599265	total: 6.6s	remaining: 21.4s
# 236:	learn: 0.5598233	total: 6.63s	remaining: 21.3s
# 237:	learn: 0.5595380	total: 6.66s	remaining: 21.3s
# 238:	learn: 0.5592873	total: 6.69s	remaining: 21.3s
# 239:	learn: 0.5592071	total: 6.72s	remaining: 21.3s
# 240:	learn: 0.5591425	total: 6.74s	remaining: 21.2s
# 241:	learn: 0.5589664	total: 6.78s	remaining: 21.2s
# 242:	learn: 0.5588159	total: 6.81s	remaining: 21.2s
# 243:	learn: 0.5587929	total: 6.83s	remaining: 21.2s
# 244:	learn: 0.5586183	total: 6.86s	remaining: 21.1s
# 245:	learn: 0.5585537	total: 6.89s	remaining: 21.1s
# 246:	learn: 0.5584356	total: 6.92s	remaining: 21.1s
# 247:	learn: 0.5583162	total: 6.95s	remaining: 21.1s
# 248:	learn: 0.5582318	total: 6.97s	remaining: 21s
# 249:	learn: 0.5581399	total: 7s	remaining: 21s
# 250:	learn: 0.5580185	total: 7.03s	remaining: 21s
# 251:	learn: 0.5577154	total: 7.06s	remaining: 21s
# 252:	learn: 0.5575050	total: 7.09s	remaining: 20.9s
# 253:	learn: 0.5573624	total: 7.12s	remaining: 20.9s
# 254:	learn: 0.5572453	total: 7.14s	remaining: 20.9s
# 255:	learn: 0.5571751	total: 7.17s	remaining: 20.8s
# 256:	learn: 0.5571160	total: 7.2s	remaining: 20.8s
# 257:	learn: 0.5570127	total: 7.23s	remaining: 20.8s
# 258:	learn: 0.5569289	total: 7.25s	remaining: 20.8s
# 259:	learn: 0.5568251	total: 7.29s	remaining: 20.7s
# 260:	learn: 0.5567255	total: 7.31s	remaining: 20.7s
# 261:	learn: 0.5565941	total: 7.34s	remaining: 20.7s
# 262:	learn: 0.5563815	total: 7.36s	remaining: 20.6s
# 263:	learn: 0.5562265	total: 7.39s	remaining: 20.6s
# 264:	learn: 0.5560124	total: 7.42s	remaining: 20.6s
# 265:	learn: 0.5558940	total: 7.45s	remaining: 20.6s
# 266:	learn: 0.5558295	total: 7.48s	remaining: 20.5s
# 267:	learn: 0.5556129	total: 7.51s	remaining: 20.5s
# 268:	learn: 0.5555405	total: 7.54s	remaining: 20.5s
# 269:	learn: 0.5553749	total: 7.57s	remaining: 20.5s
# 270:	learn: 0.5552166	total: 7.59s	remaining: 20.4s
# 271:	learn: 0.5550811	total: 7.62s	remaining: 20.4s
# 272:	learn: 0.5549843	total: 7.65s	remaining: 20.4s
# 273:	learn: 0.5548761	total: 7.68s	remaining: 20.4s
# 274:	learn: 0.5545927	total: 7.71s	remaining: 20.3s
# 275:	learn: 0.5544806	total: 7.74s	remaining: 20.3s
# 276:	learn: 0.5543847	total: 7.76s	remaining: 20.3s
# 277:	learn: 0.5542971	total: 7.79s	remaining: 20.2s
# 278:	learn: 0.5540613	total: 7.83s	remaining: 20.2s
# 279:	learn: 0.5539644	total: 7.85s	remaining: 20.2s
# 280:	learn: 0.5538827	total: 7.88s	remaining: 20.2s
# 281:	learn: 0.5537179	total: 7.91s	remaining: 20.1s
# 282:	learn: 0.5534241	total: 7.94s	remaining: 20.1s
# 283:	learn: 0.5533315	total: 7.97s	remaining: 20.1s
# 284:	learn: 0.5532142	total: 8.01s	remaining: 20.1s
# 285:	learn: 0.5531391	total: 8.04s	remaining: 20.1s
# 286:	learn: 0.5530037	total: 8.07s	remaining: 20s
# 287:	learn: 0.5527827	total: 8.1s	remaining: 20s
# 288:	learn: 0.5526804	total: 8.13s	remaining: 20s
# 289:	learn: 0.5525529	total: 8.16s	remaining: 20s
# 290:	learn: 0.5524730	total: 8.19s	remaining: 19.9s
# 291:	learn: 0.5524174	total: 8.21s	remaining: 19.9s
# 292:	learn: 0.5523577	total: 8.24s	remaining: 19.9s
# 293:	learn: 0.5521725	total: 8.28s	remaining: 19.9s
# 294:	learn: 0.5520515	total: 8.3s	remaining: 19.8s
# 295:	learn: 0.5519086	total: 8.34s	remaining: 19.8s
# 296:	learn: 0.5518253	total: 8.37s	remaining: 19.8s
# 297:	learn: 0.5517381	total: 8.39s	remaining: 19.8s
# 298:	learn: 0.5516268	total: 8.43s	remaining: 19.8s
# 299:	learn: 0.5515340	total: 8.47s	remaining: 19.8s
# 300:	learn: 0.5514834	total: 8.5s	remaining: 19.7s
# 301:	learn: 0.5513782	total: 8.54s	remaining: 19.7s
# 302:	learn: 0.5511821	total: 8.58s	remaining: 19.7s
# 303:	learn: 0.5510403	total: 8.61s	remaining: 19.7s
# 304:	learn: 0.5509530	total: 8.64s	remaining: 19.7s
# 305:	learn: 0.5508235	total: 8.67s	remaining: 19.7s
# 306:	learn: 0.5507224	total: 8.7s	remaining: 19.6s
# 307:	learn: 0.5506151	total: 8.73s	remaining: 19.6s
# 308:	learn: 0.5505027	total: 8.76s	remaining: 19.6s
# 309:	learn: 0.5504077	total: 8.79s	remaining: 19.6s
# 310:	learn: 0.5503329	total: 8.82s	remaining: 19.5s
# 311:	learn: 0.5502071	total: 8.85s	remaining: 19.5s
# 312:	learn: 0.5501208	total: 8.88s	remaining: 19.5s
# 313:	learn: 0.5500094	total: 8.91s	remaining: 19.5s
# 314:	learn: 0.5499194	total: 8.94s	remaining: 19.4s
# 315:	learn: 0.5498663	total: 8.97s	remaining: 19.4s
# 316:	learn: 0.5497759	total: 8.99s	remaining: 19.4s
# 317:	learn: 0.5496729	total: 9.02s	remaining: 19.4s
# 318:	learn: 0.5496126	total: 9.05s	remaining: 19.3s
# 319:	learn: 0.5495287	total: 9.08s	remaining: 19.3s
# 320:	learn: 0.5494530	total: 9.11s	remaining: 19.3s
# 321:	learn: 0.5493197	total: 9.14s	remaining: 19.2s
# 322:	learn: 0.5491610	total: 9.16s	remaining: 19.2s
# 323:	learn: 0.5490680	total: 9.2s	remaining: 19.2s
# 324:	learn: 0.5489823	total: 9.22s	remaining: 19.2s
# 325:	learn: 0.5489592	total: 9.25s	remaining: 19.1s
# 326:	learn: 0.5488464	total: 9.28s	remaining: 19.1s
# 327:	learn: 0.5487488	total: 9.31s	remaining: 19.1s
# 328:	learn: 0.5486921	total: 9.33s	remaining: 19s
# 329:	learn: 0.5485960	total: 9.36s	remaining: 19s
# 330:	learn: 0.5484908	total: 9.38s	remaining: 19s
# 331:	learn: 0.5484056	total: 9.41s	remaining: 18.9s
# 332:	learn: 0.5482376	total: 9.48s	remaining: 19s
# 333:	learn: 0.5481176	total: 9.54s	remaining: 19s
# 334:	learn: 0.5480149	total: 9.65s	remaining: 19.2s
# 335:	learn: 0.5479202	total: 9.71s	remaining: 19.2s
# 336:	learn: 0.5477515	total: 9.74s	remaining: 19.2s
# 337:	learn: 0.5475845	total: 9.77s	remaining: 19.1s
# 338:	learn: 0.5475388	total: 9.8s	remaining: 19.1s
# 339:	learn: 0.5474662	total: 9.84s	remaining: 19.1s
# 340:	learn: 0.5474038	total: 9.86s	remaining: 19.1s
# 341:	learn: 0.5473307	total: 9.89s	remaining: 19s
# 342:	learn: 0.5471307	total: 9.93s	remaining: 19s
# 343:	learn: 0.5470271	total: 9.96s	remaining: 19s
# 344:	learn: 0.5469342	total: 9.99s	remaining: 19s
# 345:	learn: 0.5467916	total: 10s	remaining: 18.9s
# 346:	learn: 0.5467029	total: 10s	remaining: 18.9s
# 347:	learn: 0.5466050	total: 10.1s	remaining: 18.9s
# 348:	learn: 0.5465376	total: 10.1s	remaining: 18.8s
# 349:	learn: 0.5465104	total: 10.1s	remaining: 18.8s
# 350:	learn: 0.5464565	total: 10.2s	remaining: 18.8s
# 351:	learn: 0.5463839	total: 10.2s	remaining: 18.8s
# 352:	learn: 0.5463103	total: 10.2s	remaining: 18.7s
# 353:	learn: 0.5462120	total: 10.2s	remaining: 18.7s
# 354:	learn: 0.5461130	total: 10.3s	remaining: 18.7s
# 355:	learn: 0.5460230	total: 10.3s	remaining: 18.7s
# 356:	learn: 0.5459844	total: 10.3s	remaining: 18.6s
# 357:	learn: 0.5458671	total: 10.4s	remaining: 18.6s
# 358:	learn: 0.5457814	total: 10.4s	remaining: 18.6s
# 359:	learn: 0.5457143	total: 10.4s	remaining: 18.6s
# 360:	learn: 0.5456092	total: 10.5s	remaining: 18.5s
# 361:	learn: 0.5455150	total: 10.5s	remaining: 18.5s
# 362:	learn: 0.5454134	total: 10.5s	remaining: 18.5s
# 363:	learn: 0.5451751	total: 10.6s	remaining: 18.5s
# 364:	learn: 0.5450534	total: 10.6s	remaining: 18.5s
# 365:	learn: 0.5450102	total: 10.6s	remaining: 18.4s
# 366:	learn: 0.5448925	total: 10.7s	remaining: 18.4s
# 367:	learn: 0.5448316	total: 10.7s	remaining: 18.4s
# 368:	learn: 0.5447465	total: 10.8s	remaining: 18.4s
# 369:	learn: 0.5446272	total: 10.8s	remaining: 18.4s
# 370:	learn: 0.5445317	total: 10.8s	remaining: 18.4s
# 371:	learn: 0.5444555	total: 10.9s	remaining: 18.4s
# 372:	learn: 0.5444083	total: 10.9s	remaining: 18.3s
# 373:	learn: 0.5443449	total: 10.9s	remaining: 18.3s
# 374:	learn: 0.5442763	total: 11s	remaining: 18.3s
# 375:	learn: 0.5441642	total: 11s	remaining: 18.3s
# 376:	learn: 0.5440873	total: 11s	remaining: 18.2s
# 377:	learn: 0.5439922	total: 11.1s	remaining: 18.2s
# 378:	learn: 0.5438967	total: 11.1s	remaining: 18.3s
# 379:	learn: 0.5438210	total: 11.2s	remaining: 18.3s
# 380:	learn: 0.5437911	total: 11.3s	remaining: 18.3s
# 381:	learn: 0.5436876	total: 11.3s	remaining: 18.3s
# 382:	learn: 0.5435964	total: 11.4s	remaining: 18.3s
# 383:	learn: 0.5435601	total: 11.4s	remaining: 18.3s
# 384:	learn: 0.5435220	total: 11.4s	remaining: 18.3s
# 385:	learn: 0.5434612	total: 11.5s	remaining: 18.2s
# 386:	learn: 0.5433704	total: 11.5s	remaining: 18.2s
# 387:	learn: 0.5433081	total: 11.5s	remaining: 18.2s
# 388:	learn: 0.5432691	total: 11.6s	remaining: 18.2s
# 389:	learn: 0.5432004	total: 11.6s	remaining: 18.1s
# 390:	learn: 0.5431772	total: 11.6s	remaining: 18.1s
# 391:	learn: 0.5430682	total: 11.7s	remaining: 18.1s
# 392:	learn: 0.5429918	total: 11.7s	remaining: 18.1s
# 393:	learn: 0.5429216	total: 11.7s	remaining: 18s
# 394:	learn: 0.5428332	total: 11.8s	remaining: 18s
# 395:	learn: 0.5427480	total: 11.8s	remaining: 18s
# 396:	learn: 0.5426382	total: 11.8s	remaining: 18s
# 397:	learn: 0.5425227	total: 11.9s	remaining: 17.9s
# 398:	learn: 0.5424659	total: 11.9s	remaining: 17.9s
# 399:	learn: 0.5423340	total: 11.9s	remaining: 17.9s
# 400:	learn: 0.5422629	total: 12s	remaining: 17.9s
# 401:	learn: 0.5422235	total: 12s	remaining: 17.8s
# 402:	learn: 0.5419672	total: 12s	remaining: 17.8s
# 403:	learn: 0.5419070	total: 12s	remaining: 17.8s
# 404:	learn: 0.5418086	total: 12.1s	remaining: 17.7s
# 405:	learn: 0.5417635	total: 12.1s	remaining: 17.7s
# 406:	learn: 0.5414745	total: 12.1s	remaining: 17.7s
# 407:	learn: 0.5413866	total: 12.2s	remaining: 17.6s
# 408:	learn: 0.5413224	total: 12.2s	remaining: 17.6s
# 409:	learn: 0.5413075	total: 12.2s	remaining: 17.6s
# 410:	learn: 0.5411628	total: 12.2s	remaining: 17.5s
# 411:	learn: 0.5410919	total: 12.3s	remaining: 17.5s
# 412:	learn: 0.5410136	total: 12.3s	remaining: 17.5s
# 413:	learn: 0.5409717	total: 12.3s	remaining: 17.4s
# 414:	learn: 0.5408787	total: 12.3s	remaining: 17.4s
# 415:	learn: 0.5408412	total: 12.4s	remaining: 17.4s
# 416:	learn: 0.5408014	total: 12.4s	remaining: 17.3s
# 417:	learn: 0.5407159	total: 12.4s	remaining: 17.3s
# 418:	learn: 0.5406245	total: 12.4s	remaining: 17.3s
# 419:	learn: 0.5405157	total: 12.5s	remaining: 17.2s
# 420:	learn: 0.5404539	total: 12.5s	remaining: 17.2s
# 421:	learn: 0.5403578	total: 12.5s	remaining: 17.2s
# 422:	learn: 0.5402884	total: 12.6s	remaining: 17.1s
# 423:	learn: 0.5402052	total: 12.6s	remaining: 17.1s
# 424:	learn: 0.5401404	total: 12.6s	remaining: 17.1s
# 425:	learn: 0.5401323	total: 12.6s	remaining: 17s
# 426:	learn: 0.5400853	total: 12.7s	remaining: 17s
# 427:	learn: 0.5400214	total: 12.7s	remaining: 17s
# 428:	learn: 0.5399198	total: 12.7s	remaining: 16.9s
# 429:	learn: 0.5397794	total: 12.8s	remaining: 16.9s
# 430:	learn: 0.5396197	total: 12.8s	remaining: 16.9s
# 431:	learn: 0.5395506	total: 12.8s	remaining: 16.8s
# 432:	learn: 0.5393275	total: 12.8s	remaining: 16.8s
# 433:	learn: 0.5392088	total: 12.9s	remaining: 16.8s
# 434:	learn: 0.5391346	total: 12.9s	remaining: 16.8s
# 435:	learn: 0.5390660	total: 12.9s	remaining: 16.7s
# 436:	learn: 0.5389872	total: 13s	remaining: 16.7s
# 437:	learn: 0.5389210	total: 13s	remaining: 16.7s
# 438:	learn: 0.5388854	total: 13s	remaining: 16.6s
# 439:	learn: 0.5388360	total: 13.1s	remaining: 16.6s
# 440:	learn: 0.5387487	total: 13.1s	remaining: 16.6s
# 441:	learn: 0.5386781	total: 13.1s	remaining: 16.6s
# 442:	learn: 0.5386165	total: 13.2s	remaining: 16.5s
# 443:	learn: 0.5385357	total: 13.2s	remaining: 16.5s
# 444:	learn: 0.5384873	total: 13.2s	remaining: 16.5s
# 445:	learn: 0.5384404	total: 13.2s	remaining: 16.5s
# 446:	learn: 0.5383610	total: 13.3s	remaining: 16.4s
# 447:	learn: 0.5383075	total: 13.3s	remaining: 16.4s
# 448:	learn: 0.5382614	total: 13.3s	remaining: 16.4s
# 449:	learn: 0.5382184	total: 13.4s	remaining: 16.4s
# 450:	learn: 0.5381376	total: 13.4s	remaining: 16.4s
# 451:	learn: 0.5381114	total: 13.5s	remaining: 16.3s
# 452:	learn: 0.5380324	total: 13.5s	remaining: 16.3s
# 453:	learn: 0.5380102	total: 13.5s	remaining: 16.3s
# 454:	learn: 0.5379309	total: 13.6s	remaining: 16.3s
# 455:	learn: 0.5378906	total: 13.6s	remaining: 16.2s
# 456:	learn: 0.5378259	total: 13.6s	remaining: 16.2s
# 457:	learn: 0.5377475	total: 13.7s	remaining: 16.2s
# 458:	learn: 0.5377399	total: 13.7s	remaining: 16.1s
# 459:	learn: 0.5376814	total: 13.7s	remaining: 16.1s
# 460:	learn: 0.5376231	total: 13.8s	remaining: 16.1s
# 461:	learn: 0.5375528	total: 13.8s	remaining: 16.1s
# 462:	learn: 0.5374667	total: 13.8s	remaining: 16s
# 463:	learn: 0.5373692	total: 13.9s	remaining: 16s
# 464:	learn: 0.5372877	total: 13.9s	remaining: 16s
# 465:	learn: 0.5372479	total: 13.9s	remaining: 15.9s
# 466:	learn: 0.5371794	total: 13.9s	remaining: 15.9s
# 467:	learn: 0.5371311	total: 14s	remaining: 15.9s
# 468:	learn: 0.5370515	total: 14s	remaining: 15.8s
# 469:	learn: 0.5369741	total: 14s	remaining: 15.8s
# 470:	learn: 0.5369249	total: 14s	remaining: 15.8s
# 471:	learn: 0.5368554	total: 14.1s	remaining: 15.8s
# 472:	learn: 0.5367976	total: 14.1s	remaining: 15.7s
# 473:	learn: 0.5367226	total: 14.1s	remaining: 15.7s
# 474:	learn: 0.5366615	total: 14.2s	remaining: 15.7s
# 475:	learn: 0.5366100	total: 14.2s	remaining: 15.6s
# 476:	learn: 0.5365452	total: 14.2s	remaining: 15.6s
# 477:	learn: 0.5365074	total: 14.3s	remaining: 15.6s
# 478:	learn: 0.5364025	total: 14.3s	remaining: 15.6s
# 479:	learn: 0.5363320	total: 14.3s	remaining: 15.5s
# 480:	learn: 0.5362509	total: 14.4s	remaining: 15.5s
# 481:	learn: 0.5361515	total: 14.4s	remaining: 15.5s
# 482:	learn: 0.5360920	total: 14.4s	remaining: 15.5s
# 483:	learn: 0.5360341	total: 14.5s	remaining: 15.4s
# 484:	learn: 0.5359677	total: 14.5s	remaining: 15.4s
# 485:	learn: 0.5358707	total: 14.5s	remaining: 15.4s
# 486:	learn: 0.5357601	total: 14.6s	remaining: 15.4s
# 487:	learn: 0.5356611	total: 14.6s	remaining: 15.3s
# 488:	learn: 0.5355543	total: 14.7s	remaining: 15.3s
# 489:	learn: 0.5355200	total: 14.7s	remaining: 15.3s
# 490:	learn: 0.5354195	total: 14.7s	remaining: 15.3s
# 491:	learn: 0.5353672	total: 14.7s	remaining: 15.2s
# 492:	learn: 0.5352585	total: 14.8s	remaining: 15.2s
# 493:	learn: 0.5351724	total: 14.8s	remaining: 15.2s
# 494:	learn: 0.5351147	total: 14.8s	remaining: 15.1s
# 495:	learn: 0.5350281	total: 14.9s	remaining: 15.1s
# 496:	learn: 0.5349000	total: 14.9s	remaining: 15.1s
# 497:	learn: 0.5348606	total: 14.9s	remaining: 15s
# 498:	learn: 0.5347803	total: 15s	remaining: 15s
# 499:	learn: 0.5347622	total: 15s	remaining: 15s
# 500:	learn: 0.5347117	total: 15s	remaining: 14.9s
# 501:	learn: 0.5346723	total: 15s	remaining: 14.9s
# 502:	learn: 0.5345779	total: 15.1s	remaining: 14.9s
# 503:	learn: 0.5345477	total: 15.1s	remaining: 14.9s
# 504:	learn: 0.5344460	total: 15.1s	remaining: 14.8s
# 505:	learn: 0.5343737	total: 15.1s	remaining: 14.8s
# 506:	learn: 0.5343387	total: 15.2s	remaining: 14.8s
# 507:	learn: 0.5343322	total: 15.2s	remaining: 14.7s
# 508:	learn: 0.5342806	total: 15.2s	remaining: 14.7s
# 509:	learn: 0.5341876	total: 15.3s	remaining: 14.7s
# 510:	learn: 0.5341402	total: 15.3s	remaining: 14.6s
# 511:	learn: 0.5340902	total: 15.3s	remaining: 14.6s
# 512:	learn: 0.5340114	total: 15.4s	remaining: 14.6s
# 513:	learn: 0.5339544	total: 15.4s	remaining: 14.6s
# 514:	learn: 0.5339020	total: 15.4s	remaining: 14.5s
# 515:	learn: 0.5338518	total: 15.5s	remaining: 14.5s
# 516:	learn: 0.5337945	total: 15.5s	remaining: 14.5s
# 517:	learn: 0.5337253	total: 15.5s	remaining: 14.5s
# 518:	learn: 0.5336779	total: 15.6s	remaining: 14.4s
# 519:	learn: 0.5335948	total: 15.6s	remaining: 14.4s
# 520:	learn: 0.5335510	total: 15.6s	remaining: 14.4s
# 521:	learn: 0.5335054	total: 15.7s	remaining: 14.3s
# 522:	learn: 0.5333836	total: 15.7s	remaining: 14.3s
# 523:	learn: 0.5333285	total: 15.8s	remaining: 14.3s
# 524:	learn: 0.5331574	total: 15.8s	remaining: 14.3s
# 525:	learn: 0.5331200	total: 15.8s	remaining: 14.3s
# 526:	learn: 0.5330866	total: 15.8s	remaining: 14.2s
# 527:	learn: 0.5330299	total: 15.9s	remaining: 14.2s
# 528:	learn: 0.5329817	total: 15.9s	remaining: 14.2s
# 529:	learn: 0.5329234	total: 15.9s	remaining: 14.1s
# 530:	learn: 0.5328376	total: 16s	remaining: 14.1s
# 531:	learn: 0.5328314	total: 16s	remaining: 14.1s
# 532:	learn: 0.5327593	total: 16.1s	remaining: 14.1s
# 533:	learn: 0.5327054	total: 16.1s	remaining: 14.1s
# 534:	learn: 0.5325766	total: 16.1s	remaining: 14s
# 535:	learn: 0.5325032	total: 16.2s	remaining: 14s
# 536:	learn: 0.5324002	total: 16.2s	remaining: 14s
# 537:	learn: 0.5323085	total: 16.3s	remaining: 14s
# 538:	learn: 0.5322836	total: 16.3s	remaining: 14s
# 539:	learn: 0.5322409	total: 16.4s	remaining: 13.9s
# 540:	learn: 0.5322057	total: 16.4s	remaining: 13.9s
# 541:	learn: 0.5320869	total: 16.4s	remaining: 13.9s
# 542:	learn: 0.5320214	total: 16.5s	remaining: 13.9s
# 543:	learn: 0.5319561	total: 16.5s	remaining: 13.8s
# 544:	learn: 0.5318818	total: 16.5s	remaining: 13.8s
# 545:	learn: 0.5318495	total: 16.6s	remaining: 13.8s
# 546:	learn: 0.5317741	total: 16.6s	remaining: 13.8s
# 547:	learn: 0.5316991	total: 16.6s	remaining: 13.7s
# 548:	learn: 0.5316912	total: 16.7s	remaining: 13.7s
# 549:	learn: 0.5316468	total: 16.7s	remaining: 13.7s
# 550:	learn: 0.5315843	total: 16.8s	remaining: 13.7s
# 551:	learn: 0.5315482	total: 16.8s	remaining: 13.6s
# 552:	learn: 0.5314626	total: 16.8s	remaining: 13.6s
# 553:	learn: 0.5314097	total: 16.9s	remaining: 13.6s
# 554:	learn: 0.5313581	total: 16.9s	remaining: 13.6s
# 555:	learn: 0.5313167	total: 17s	remaining: 13.5s
# 556:	learn: 0.5312354	total: 17s	remaining: 13.5s
# 557:	learn: 0.5312026	total: 17s	remaining: 13.5s
# 558:	learn: 0.5311556	total: 17.1s	remaining: 13.5s
# 559:	learn: 0.5310798	total: 17.1s	remaining: 13.4s
# 560:	learn: 0.5310330	total: 17.1s	remaining: 13.4s
# 561:	learn: 0.5310023	total: 17.2s	remaining: 13.4s
# 562:	learn: 0.5309527	total: 17.2s	remaining: 13.4s
# 563:	learn: 0.5308853	total: 17.2s	remaining: 13.3s
# 564:	learn: 0.5308308	total: 17.3s	remaining: 13.3s
# 565:	learn: 0.5307889	total: 17.3s	remaining: 13.3s
# 566:	learn: 0.5307244	total: 17.3s	remaining: 13.2s
# 567:	learn: 0.5306829	total: 17.4s	remaining: 13.2s
# 568:	learn: 0.5305745	total: 17.4s	remaining: 13.2s
# 569:	learn: 0.5305098	total: 17.4s	remaining: 13.2s
# 570:	learn: 0.5304420	total: 17.5s	remaining: 13.1s
# 571:	learn: 0.5303825	total: 17.5s	remaining: 13.1s
# 572:	learn: 0.5303056	total: 17.5s	remaining: 13.1s
# 573:	learn: 0.5302767	total: 17.6s	remaining: 13s
# 574:	learn: 0.5302153	total: 17.6s	remaining: 13s
# 575:	learn: 0.5301925	total: 17.6s	remaining: 13s
# 576:	learn: 0.5301549	total: 17.7s	remaining: 12.9s
# 577:	learn: 0.5299374	total: 17.7s	remaining: 12.9s
# 578:	learn: 0.5299074	total: 17.7s	remaining: 12.9s
# 579:	learn: 0.5298217	total: 17.8s	remaining: 12.9s
# 580:	learn: 0.5297374	total: 17.8s	remaining: 12.8s
# 581:	learn: 0.5296787	total: 17.8s	remaining: 12.8s
# 582:	learn: 0.5295902	total: 17.9s	remaining: 12.8s
# 583:	learn: 0.5295553	total: 17.9s	remaining: 12.7s
# 584:	learn: 0.5295175	total: 17.9s	remaining: 12.7s
# 585:	learn: 0.5294178	total: 18s	remaining: 12.7s
# 586:	learn: 0.5293386	total: 18s	remaining: 12.7s
# 587:	learn: 0.5292370	total: 18s	remaining: 12.6s
# 588:	learn: 0.5291478	total: 18.1s	remaining: 12.6s
# 589:	learn: 0.5291102	total: 18.1s	remaining: 12.6s
# 590:	learn: 0.5290891	total: 18.1s	remaining: 12.5s
# 591:	learn: 0.5290493	total: 18.2s	remaining: 12.5s
# 592:	learn: 0.5289764	total: 18.2s	remaining: 12.5s
# 593:	learn: 0.5289382	total: 18.2s	remaining: 12.5s
# 594:	learn: 0.5288946	total: 18.3s	remaining: 12.4s
# 595:	learn: 0.5288246	total: 18.3s	remaining: 12.4s
# 596:	learn: 0.5288013	total: 18.3s	remaining: 12.4s
# 597:	learn: 0.5287267	total: 18.3s	remaining: 12.3s
# 598:	learn: 0.5286995	total: 18.4s	remaining: 12.3s
# 599:	learn: 0.5286285	total: 18.4s	remaining: 12.3s
# 600:	learn: 0.5285810	total: 18.4s	remaining: 12.2s
# 601:	learn: 0.5285512	total: 18.5s	remaining: 12.2s
# 602:	learn: 0.5284506	total: 18.5s	remaining: 12.2s
# 603:	learn: 0.5283850	total: 18.5s	remaining: 12.1s
# 604:	learn: 0.5283099	total: 18.5s	remaining: 12.1s
# 605:	learn: 0.5282761	total: 18.6s	remaining: 12.1s
# 606:	learn: 0.5282415	total: 18.6s	remaining: 12s
# 607:	learn: 0.5281783	total: 18.6s	remaining: 12s
# 608:	learn: 0.5281437	total: 18.7s	remaining: 12s
# 609:	learn: 0.5280273	total: 18.7s	remaining: 12s
# 610:	learn: 0.5279694	total: 18.7s	remaining: 11.9s
# 611:	learn: 0.5279434	total: 18.8s	remaining: 11.9s
# 612:	learn: 0.5278482	total: 18.8s	remaining: 11.9s
# 613:	learn: 0.5277956	total: 18.8s	remaining: 11.8s
# 614:	learn: 0.5276630	total: 18.9s	remaining: 11.8s
# 615:	learn: 0.5276237	total: 18.9s	remaining: 11.8s
# 616:	learn: 0.5275405	total: 18.9s	remaining: 11.8s
# 617:	learn: 0.5275043	total: 19s	remaining: 11.7s
# 618:	learn: 0.5274814	total: 19s	remaining: 11.7s
# 619:	learn: 0.5274307	total: 19s	remaining: 11.7s
# 620:	learn: 0.5273402	total: 19s	remaining: 11.6s
# 621:	learn: 0.5273087	total: 19.1s	remaining: 11.6s
# 622:	learn: 0.5272524	total: 19.1s	remaining: 11.6s
# 623:	learn: 0.5272054	total: 19.1s	remaining: 11.5s
# 624:	learn: 0.5271905	total: 19.2s	remaining: 11.5s
# 625:	learn: 0.5271452	total: 19.2s	remaining: 11.5s
# 626:	learn: 0.5271064	total: 19.2s	remaining: 11.4s
# 627:	learn: 0.5270105	total: 19.2s	remaining: 11.4s
# 628:	learn: 0.5269723	total: 19.3s	remaining: 11.4s
# 629:	learn: 0.5269125	total: 19.3s	remaining: 11.3s
# 630:	learn: 0.5268035	total: 19.3s	remaining: 11.3s
# 631:	learn: 0.5267226	total: 19.3s	remaining: 11.3s
# 632:	learn: 0.5267001	total: 19.4s	remaining: 11.2s
# 633:	learn: 0.5266319	total: 19.4s	remaining: 11.2s
# 634:	learn: 0.5265776	total: 19.4s	remaining: 11.2s
# 635:	learn: 0.5265396	total: 19.5s	remaining: 11.1s
# 636:	learn: 0.5264766	total: 19.5s	remaining: 11.1s
# 637:	learn: 0.5264413	total: 19.5s	remaining: 11.1s
# 638:	learn: 0.5263761	total: 19.5s	remaining: 11s
# 639:	learn: 0.5262982	total: 19.6s	remaining: 11s
# 640:	learn: 0.5262342	total: 19.6s	remaining: 11s
# 641:	learn: 0.5261551	total: 19.6s	remaining: 10.9s
# 642:	learn: 0.5261204	total: 19.7s	remaining: 10.9s
# 643:	learn: 0.5260622	total: 19.7s	remaining: 10.9s
# 644:	learn: 0.5260395	total: 19.7s	remaining: 10.9s
# 645:	learn: 0.5259758	total: 19.8s	remaining: 10.8s
# 646:	learn: 0.5259335	total: 19.8s	remaining: 10.8s
# 647:	learn: 0.5258793	total: 19.9s	remaining: 10.8s
# 648:	learn: 0.5257871	total: 19.9s	remaining: 10.8s
# 649:	learn: 0.5257508	total: 19.9s	remaining: 10.7s
# 650:	learn: 0.5257164	total: 20s	remaining: 10.7s
# 651:	learn: 0.5256758	total: 20s	remaining: 10.7s
# 652:	learn: 0.5256383	total: 20s	remaining: 10.6s
# 653:	learn: 0.5255771	total: 20.1s	remaining: 10.6s
# 654:	learn: 0.5255410	total: 20.1s	remaining: 10.6s
# 655:	learn: 0.5255072	total: 20.1s	remaining: 10.5s
# 656:	learn: 0.5254461	total: 20.1s	remaining: 10.5s
# 657:	learn: 0.5254272	total: 20.2s	remaining: 10.5s
# 658:	learn: 0.5253845	total: 20.2s	remaining: 10.4s
# 659:	learn: 0.5253089	total: 20.2s	remaining: 10.4s
# 660:	learn: 0.5252756	total: 20.2s	remaining: 10.4s
# 661:	learn: 0.5252122	total: 20.3s	remaining: 10.4s
# 662:	learn: 0.5251819	total: 20.3s	remaining: 10.3s
# 663:	learn: 0.5251181	total: 20.3s	remaining: 10.3s
# 664:	learn: 0.5250453	total: 20.4s	remaining: 10.3s
# 665:	learn: 0.5249396	total: 20.4s	remaining: 10.2s
# 666:	learn: 0.5248589	total: 20.4s	remaining: 10.2s
# 667:	learn: 0.5247926	total: 20.5s	remaining: 10.2s
# 668:	learn: 0.5247598	total: 20.5s	remaining: 10.1s
# 669:	learn: 0.5247339	total: 20.5s	remaining: 10.1s
# 670:	learn: 0.5246633	total: 20.6s	remaining: 10.1s
# 671:	learn: 0.5245920	total: 20.6s	remaining: 10s
# 672:	learn: 0.5245089	total: 20.7s	remaining: 10.1s
# 673:	learn: 0.5244319	total: 20.7s	remaining: 10s
# 674:	learn: 0.5244097	total: 20.8s	remaining: 9.99s
# 675:	learn: 0.5243676	total: 20.8s	remaining: 9.96s
# 676:	learn: 0.5243070	total: 20.8s	remaining: 9.93s
# 677:	learn: 0.5242743	total: 20.8s	remaining: 9.9s
# 678:	learn: 0.5242141	total: 20.9s	remaining: 9.86s
# 679:	learn: 0.5241598	total: 20.9s	remaining: 9.83s
# 680:	learn: 0.5240522	total: 20.9s	remaining: 9.8s
# 681:	learn: 0.5240008	total: 20.9s	remaining: 9.77s
# 682:	learn: 0.5239033	total: 21s	remaining: 9.74s
# 683:	learn: 0.5238601	total: 21s	remaining: 9.71s
# 684:	learn: 0.5237910	total: 21s	remaining: 9.68s
# 685:	learn: 0.5237657	total: 21.1s	remaining: 9.64s
# 686:	learn: 0.5236959	total: 21.1s	remaining: 9.62s
# 687:	learn: 0.5236546	total: 21.1s	remaining: 9.59s
# 688:	learn: 0.5236074	total: 21.2s	remaining: 9.55s
# 689:	learn: 0.5236007	total: 21.2s	remaining: 9.53s
# 690:	learn: 0.5235272	total: 21.2s	remaining: 9.5s
# 691:	learn: 0.5234776	total: 21.3s	remaining: 9.47s
# 692:	learn: 0.5234065	total: 21.3s	remaining: 9.45s
# 693:	learn: 0.5233637	total: 21.4s	remaining: 9.42s
# 694:	learn: 0.5233038	total: 21.4s	remaining: 9.39s
# 695:	learn: 0.5232428	total: 21.4s	remaining: 9.37s
# 696:	learn: 0.5232032	total: 21.5s	remaining: 9.34s
# 697:	learn: 0.5231799	total: 21.5s	remaining: 9.31s
# 698:	learn: 0.5230980	total: 21.6s	remaining: 9.28s
# 699:	learn: 0.5230035	total: 21.6s	remaining: 9.25s
# 700:	learn: 0.5229455	total: 21.6s	remaining: 9.22s
# 701:	learn: 0.5229209	total: 21.7s	remaining: 9.2s
# 702:	learn: 0.5228856	total: 21.7s	remaining: 9.17s
# 703:	learn: 0.5228730	total: 21.7s	remaining: 9.14s
# 704:	learn: 0.5228021	total: 21.8s	remaining: 9.12s
# 705:	learn: 0.5227285	total: 21.8s	remaining: 9.09s
# 706:	learn: 0.5226709	total: 21.9s	remaining: 9.07s
# 707:	learn: 0.5226061	total: 21.9s	remaining: 9.04s
# 708:	learn: 0.5225715	total: 22s	remaining: 9.01s
# 709:	learn: 0.5225539	total: 22s	remaining: 8.98s
# 710:	learn: 0.5224977	total: 22s	remaining: 8.96s
# 711:	learn: 0.5224686	total: 22.1s	remaining: 8.93s
# 712:	learn: 0.5224451	total: 22.1s	remaining: 8.9s
# 713:	learn: 0.5224031	total: 22.1s	remaining: 8.87s
# 714:	learn: 0.5223580	total: 22.2s	remaining: 8.84s
# 715:	learn: 0.5223362	total: 22.2s	remaining: 8.81s
# 716:	learn: 0.5222696	total: 22.3s	remaining: 8.78s
# 717:	learn: 0.5222464	total: 22.3s	remaining: 8.75s
# 718:	learn: 0.5222270	total: 22.3s	remaining: 8.72s
# 719:	learn: 0.5221050	total: 22.3s	remaining: 8.69s
# 720:	learn: 0.5220594	total: 22.4s	remaining: 8.65s
# 721:	learn: 0.5220412	total: 22.4s	remaining: 8.62s
# 722:	learn: 0.5220115	total: 22.4s	remaining: 8.59s
# 723:	learn: 0.5219818	total: 22.5s	remaining: 8.56s
# 724:	learn: 0.5219225	total: 22.5s	remaining: 8.54s
# 725:	learn: 0.5218942	total: 22.5s	remaining: 8.51s
# 726:	learn: 0.5218691	total: 22.6s	remaining: 8.48s
# 727:	learn: 0.5217932	total: 22.6s	remaining: 8.45s
# 728:	learn: 0.5217426	total: 22.6s	remaining: 8.42s
# 729:	learn: 0.5217230	total: 22.7s	remaining: 8.39s
# 730:	learn: 0.5216389	total: 22.7s	remaining: 8.37s
# 731:	learn: 0.5215969	total: 22.8s	remaining: 8.34s
# 732:	learn: 0.5215682	total: 22.8s	remaining: 8.31s
# 733:	learn: 0.5215336	total: 22.8s	remaining: 8.28s
# 734:	learn: 0.5214840	total: 22.9s	remaining: 8.25s
# 735:	learn: 0.5214343	total: 22.9s	remaining: 8.22s
# 736:	learn: 0.5214141	total: 23s	remaining: 8.2s
# 737:	learn: 0.5213741	total: 23s	remaining: 8.17s
# 738:	learn: 0.5213511	total: 23s	remaining: 8.13s
# 739:	learn: 0.5212958	total: 23.1s	remaining: 8.11s
# 740:	learn: 0.5212508	total: 23.1s	remaining: 8.07s
# 741:	learn: 0.5212011	total: 23.1s	remaining: 8.04s
# 742:	learn: 0.5211655	total: 23.2s	remaining: 8.02s
# 743:	learn: 0.5211243	total: 23.2s	remaining: 8s
# 744:	learn: 0.5210759	total: 23.3s	remaining: 7.97s
# 745:	learn: 0.5210267	total: 23.3s	remaining: 7.94s
# 746:	learn: 0.5209833	total: 23.3s	remaining: 7.91s
# 747:	learn: 0.5209397	total: 23.4s	remaining: 7.88s
# 748:	learn: 0.5209244	total: 23.4s	remaining: 7.84s
# 749:	learn: 0.5208950	total: 23.4s	remaining: 7.81s
# 750:	learn: 0.5208674	total: 23.5s	remaining: 7.78s
# 751:	learn: 0.5208064	total: 23.5s	remaining: 7.75s
# 752:	learn: 0.5206250	total: 23.5s	remaining: 7.72s
# 753:	learn: 0.5204766	total: 23.6s	remaining: 7.69s
# 754:	learn: 0.5204453	total: 23.6s	remaining: 7.67s
# 755:	learn: 0.5204220	total: 23.7s	remaining: 7.64s
# 756:	learn: 0.5203818	total: 23.7s	remaining: 7.61s
# 757:	learn: 0.5203189	total: 23.8s	remaining: 7.58s
# 758:	learn: 0.5202603	total: 23.8s	remaining: 7.56s
# 759:	learn: 0.5202088	total: 23.8s	remaining: 7.53s
# 760:	learn: 0.5201561	total: 23.9s	remaining: 7.5s
# 761:	learn: 0.5201274	total: 23.9s	remaining: 7.47s
# 762:	learn: 0.5201108	total: 24s	remaining: 7.44s
# 763:	learn: 0.5200830	total: 24s	remaining: 7.41s
# 764:	learn: 0.5200561	total: 24s	remaining: 7.38s
# 765:	learn: 0.5200241	total: 24.1s	remaining: 7.35s
# 766:	learn: 0.5199773	total: 24.1s	remaining: 7.32s
# 767:	learn: 0.5199511	total: 24.1s	remaining: 7.29s
# 768:	learn: 0.5199180	total: 24.2s	remaining: 7.26s
# 769:	learn: 0.5198867	total: 24.2s	remaining: 7.23s
# 770:	learn: 0.5198194	total: 24.2s	remaining: 7.2s
# 771:	learn: 0.5197404	total: 24.3s	remaining: 7.17s
# 772:	learn: 0.5197183	total: 24.3s	remaining: 7.14s
# 773:	learn: 0.5196778	total: 24.3s	remaining: 7.11s
# 774:	learn: 0.5196241	total: 24.4s	remaining: 7.08s
# 775:	learn: 0.5195821	total: 24.4s	remaining: 7.05s
# 776:	learn: 0.5195393	total: 24.4s	remaining: 7.02s
# 777:	learn: 0.5194580	total: 24.5s	remaining: 6.99s
# 778:	learn: 0.5194229	total: 24.5s	remaining: 6.96s
# 779:	learn: 0.5194164	total: 24.6s	remaining: 6.92s
# 780:	learn: 0.5193691	total: 24.6s	remaining: 6.89s
# 781:	learn: 0.5193356	total: 24.6s	remaining: 6.86s
# 782:	learn: 0.5193238	total: 24.6s	remaining: 6.83s
# 783:	learn: 0.5192744	total: 24.7s	remaining: 6.8s
# 784:	learn: 0.5191697	total: 24.7s	remaining: 6.77s
# 785:	learn: 0.5191433	total: 24.8s	remaining: 6.74s
# 786:	learn: 0.5190863	total: 24.8s	remaining: 6.71s
# 787:	learn: 0.5190624	total: 24.8s	remaining: 6.68s
# 788:	learn: 0.5190200	total: 24.9s	remaining: 6.65s
# 789:	learn: 0.5189662	total: 24.9s	remaining: 6.62s
# 790:	learn: 0.5189612	total: 24.9s	remaining: 6.59s
# 791:	learn: 0.5189303	total: 25s	remaining: 6.56s
# 792:	learn: 0.5188956	total: 25s	remaining: 6.53s
# 793:	learn: 0.5188683	total: 25s	remaining: 6.49s
# 794:	learn: 0.5188516	total: 25.1s	remaining: 6.46s
# 795:	learn: 0.5188341	total: 25.1s	remaining: 6.43s
# 796:	learn: 0.5188144	total: 25.1s	remaining: 6.4s
# 797:	learn: 0.5187758	total: 25.2s	remaining: 6.37s
# 798:	learn: 0.5187713	total: 25.2s	remaining: 6.34s
# 799:	learn: 0.5187134	total: 25.2s	remaining: 6.31s
# 800:	learn: 0.5186754	total: 25.3s	remaining: 6.27s
# 801:	learn: 0.5186442	total: 25.3s	remaining: 6.24s
# 802:	learn: 0.5186066	total: 25.3s	remaining: 6.21s
# 803:	learn: 0.5185739	total: 25.4s	remaining: 6.18s
# 804:	learn: 0.5184817	total: 25.4s	remaining: 6.15s
# 805:	learn: 0.5184209	total: 25.4s	remaining: 6.12s
# 806:	learn: 0.5183668	total: 25.5s	remaining: 6.09s
# 807:	learn: 0.5183373	total: 25.5s	remaining: 6.06s
# 808:	learn: 0.5182995	total: 25.5s	remaining: 6.03s
# 809:	learn: 0.5182433	total: 25.6s	remaining: 6s
# 810:	learn: 0.5181837	total: 25.6s	remaining: 5.96s
# 811:	learn: 0.5181373	total: 25.6s	remaining: 5.93s
# 812:	learn: 0.5181042	total: 25.7s	remaining: 5.91s
# 813:	learn: 0.5180176	total: 25.7s	remaining: 5.87s
# 814:	learn: 0.5179522	total: 25.7s	remaining: 5.84s
# 815:	learn: 0.5179483	total: 25.8s	remaining: 5.81s
# 816:	learn: 0.5178744	total: 25.8s	remaining: 5.78s
# 817:	learn: 0.5177893	total: 25.9s	remaining: 5.75s
# 818:	learn: 0.5177324	total: 25.9s	remaining: 5.72s
# 819:	learn: 0.5176694	total: 25.9s	remaining: 5.69s
# 820:	learn: 0.5176476	total: 26s	remaining: 5.66s
# 821:	learn: 0.5175859	total: 26s	remaining: 5.64s
# 822:	learn: 0.5175696	total: 26.1s	remaining: 5.61s
# 823:	learn: 0.5175436	total: 26.1s	remaining: 5.58s
# 824:	learn: 0.5175172	total: 26.1s	remaining: 5.54s
# 825:	learn: 0.5174640	total: 26.2s	remaining: 5.51s
# 826:	learn: 0.5174317	total: 26.2s	remaining: 5.48s
# 827:	learn: 0.5173775	total: 26.3s	remaining: 5.45s
# 828:	learn: 0.5173654	total: 26.3s	remaining: 5.42s
# 829:	learn: 0.5173105	total: 26.3s	remaining: 5.39s
# 830:	learn: 0.5172896	total: 26.4s	remaining: 5.36s
# 831:	learn: 0.5172558	total: 26.4s	remaining: 5.33s
# 832:	learn: 0.5172206	total: 26.4s	remaining: 5.3s
# 833:	learn: 0.5171971	total: 26.5s	remaining: 5.27s
# 834:	learn: 0.5171694	total: 26.5s	remaining: 5.24s
# 835:	learn: 0.5171333	total: 26.6s	remaining: 5.21s
# 836:	learn: 0.5170839	total: 26.6s	remaining: 5.18s
# 837:	learn: 0.5170600	total: 26.6s	remaining: 5.15s
# 838:	learn: 0.5170219	total: 26.7s	remaining: 5.12s
# 839:	learn: 0.5169449	total: 26.7s	remaining: 5.09s
# 840:	learn: 0.5168693	total: 26.8s	remaining: 5.07s
# 841:	learn: 0.5168482	total: 26.9s	remaining: 5.04s
# 842:	learn: 0.5167760	total: 26.9s	remaining: 5.02s
# 843:	learn: 0.5167384	total: 27s	remaining: 4.99s
# 844:	learn: 0.5166741	total: 27s	remaining: 4.96s
# 845:	learn: 0.5166272	total: 27.1s	remaining: 4.92s
# 846:	learn: 0.5166107	total: 27.1s	remaining: 4.89s
# 847:	learn: 0.5165924	total: 27.1s	remaining: 4.86s
# 848:	learn: 0.5165696	total: 27.2s	remaining: 4.83s
# 849:	learn: 0.5165027	total: 27.2s	remaining: 4.8s
# 850:	learn: 0.5164441	total: 27.2s	remaining: 4.77s
# 851:	learn: 0.5163952	total: 27.3s	remaining: 4.74s
# 852:	learn: 0.5163354	total: 27.3s	remaining: 4.71s
# 853:	learn: 0.5162911	total: 27.4s	remaining: 4.68s
# 854:	learn: 0.5162558	total: 27.4s	remaining: 4.65s
# 855:	learn: 0.5161922	total: 27.5s	remaining: 4.62s
# 856:	learn: 0.5161574	total: 27.5s	remaining: 4.59s
# 857:	learn: 0.5161475	total: 27.5s	remaining: 4.56s
# 858:	learn: 0.5161243	total: 27.6s	remaining: 4.53s
# 859:	learn: 0.5160816	total: 27.6s	remaining: 4.5s
# 860:	learn: 0.5160308	total: 27.7s	remaining: 4.47s
# 861:	learn: 0.5159693	total: 27.7s	remaining: 4.44s
# 862:	learn: 0.5159599	total: 27.7s	remaining: 4.4s
# 863:	learn: 0.5159059	total: 27.8s	remaining: 4.37s
# 864:	learn: 0.5158618	total: 27.8s	remaining: 4.34s
# 865:	learn: 0.5158096	total: 27.8s	remaining: 4.31s
# 866:	learn: 0.5157507	total: 27.9s	remaining: 4.28s
# 867:	learn: 0.5156873	total: 27.9s	remaining: 4.25s
# 868:	learn: 0.5156475	total: 27.9s	remaining: 4.21s
# 869:	learn: 0.5156181	total: 28s	remaining: 4.18s
# 870:	learn: 0.5155965	total: 28s	remaining: 4.15s
# 871:	learn: 0.5155624	total: 28s	remaining: 4.11s
# 872:	learn: 0.5155268	total: 28.1s	remaining: 4.08s
# 873:	learn: 0.5154588	total: 28.1s	remaining: 4.05s
# 874:	learn: 0.5153826	total: 28.1s	remaining: 4.01s
# 875:	learn: 0.5153399	total: 28.1s	remaining: 3.98s
# 876:	learn: 0.5153182	total: 28.2s	remaining: 3.95s
# 877:	learn: 0.5152332	total: 28.2s	remaining: 3.92s
# 878:	learn: 0.5151838	total: 28.2s	remaining: 3.88s
# 879:	learn: 0.5151509	total: 28.2s	remaining: 3.85s
# 880:	learn: 0.5151137	total: 28.3s	remaining: 3.82s
# 881:	learn: 0.5150585	total: 28.3s	remaining: 3.79s
# 882:	learn: 0.5150029	total: 28.3s	remaining: 3.75s
# 883:	learn: 0.5149683	total: 28.4s	remaining: 3.72s
# 884:	learn: 0.5149090	total: 28.4s	remaining: 3.69s
# 885:	learn: 0.5148611	total: 28.4s	remaining: 3.66s
# 886:	learn: 0.5148297	total: 28.4s	remaining: 3.62s
# 887:	learn: 0.5147813	total: 28.5s	remaining: 3.59s
# 888:	learn: 0.5147411	total: 28.5s	remaining: 3.56s
# 889:	learn: 0.5147000	total: 28.6s	remaining: 3.53s
# 890:	learn: 0.5146552	total: 28.6s	remaining: 3.5s
# 891:	learn: 0.5146268	total: 28.6s	remaining: 3.46s
# 892:	learn: 0.5145938	total: 28.7s	remaining: 3.43s
# 893:	learn: 0.5145744	total: 28.7s	remaining: 3.4s
# 894:	learn: 0.5145396	total: 28.7s	remaining: 3.37s
# 895:	learn: 0.5145357	total: 28.7s	remaining: 3.34s
# 896:	learn: 0.5145090	total: 28.8s	remaining: 3.3s
# 897:	learn: 0.5144881	total: 28.8s	remaining: 3.27s
# 898:	learn: 0.5144290	total: 28.8s	remaining: 3.24s
# 899:	learn: 0.5143808	total: 28.9s	remaining: 3.21s
# 900:	learn: 0.5143656	total: 28.9s	remaining: 3.17s
# 901:	learn: 0.5143348	total: 28.9s	remaining: 3.14s
# 902:	learn: 0.5143079	total: 28.9s	remaining: 3.11s
# 903:	learn: 0.5142632	total: 29s	remaining: 3.08s
# 904:	learn: 0.5142181	total: 29s	remaining: 3.04s
# 905:	learn: 0.5141755	total: 29s	remaining: 3.01s
# 906:	learn: 0.5141360	total: 29.1s	remaining: 2.98s
# 907:	learn: 0.5141002	total: 29.1s	remaining: 2.95s
# 908:	learn: 0.5140670	total: 29.1s	remaining: 2.92s
# 909:	learn: 0.5139987	total: 29.2s	remaining: 2.88s
# 910:	learn: 0.5139601	total: 29.2s	remaining: 2.85s
# 911:	learn: 0.5139289	total: 29.2s	remaining: 2.82s
# 912:	learn: 0.5138896	total: 29.2s	remaining: 2.79s
# 913:	learn: 0.5138573	total: 29.3s	remaining: 2.75s
# 914:	learn: 0.5137830	total: 29.3s	remaining: 2.72s
# 915:	learn: 0.5136782	total: 29.3s	remaining: 2.69s
# 916:	learn: 0.5136466	total: 29.4s	remaining: 2.66s
# 917:	learn: 0.5136274	total: 29.4s	remaining: 2.63s
# 918:	learn: 0.5135970	total: 29.4s	remaining: 2.59s
# 919:	learn: 0.5135548	total: 29.5s	remaining: 2.56s
# 920:	learn: 0.5135174	total: 29.5s	remaining: 2.53s
# 921:	learn: 0.5134820	total: 29.5s	remaining: 2.5s
# 922:	learn: 0.5134362	total: 29.6s	remaining: 2.46s
# 923:	learn: 0.5133158	total: 29.6s	remaining: 2.43s
# 924:	learn: 0.5132602	total: 29.6s	remaining: 2.4s
# 925:	learn: 0.5132361	total: 29.7s	remaining: 2.37s
# 926:	learn: 0.5131932	total: 29.7s	remaining: 2.34s
# 927:	learn: 0.5131705	total: 29.7s	remaining: 2.31s
# 928:	learn: 0.5131546	total: 29.7s	remaining: 2.27s
# 929:	learn: 0.5131415	total: 29.8s	remaining: 2.24s
# 930:	learn: 0.5131245	total: 29.8s	remaining: 2.21s
# 931:	learn: 0.5131000	total: 29.8s	remaining: 2.17s
# 932:	learn: 0.5130771	total: 29.8s	remaining: 2.14s
# 933:	learn: 0.5130445	total: 29.9s	remaining: 2.11s
# 934:	learn: 0.5130111	total: 29.9s	remaining: 2.08s
# 935:	learn: 0.5129692	total: 29.9s	remaining: 2.04s
# 936:	learn: 0.5129383	total: 29.9s	remaining: 2.01s
# 937:	learn: 0.5129108	total: 30s	remaining: 1.98s
# 938:	learn: 0.5128889	total: 30s	remaining: 1.95s
# 939:	learn: 0.5128328	total: 30s	remaining: 1.92s
# 940:	learn: 0.5128225	total: 30.1s	remaining: 1.88s
# 941:	learn: 0.5127804	total: 30.1s	remaining: 1.85s
# 942:	learn: 0.5126897	total: 30.1s	remaining: 1.82s
# 943:	learn: 0.5126605	total: 30.1s	remaining: 1.79s
# 944:	learn: 0.5126073	total: 30.2s	remaining: 1.75s
# 945:	learn: 0.5125363	total: 30.2s	remaining: 1.72s
# 946:	learn: 0.5125114	total: 30.2s	remaining: 1.69s
# 947:	learn: 0.5124688	total: 30.2s	remaining: 1.66s
# 948:	learn: 0.5124499	total: 30.3s	remaining: 1.63s
# 949:	learn: 0.5124045	total: 30.3s	remaining: 1.59s
# 950:	learn: 0.5123850	total: 30.3s	remaining: 1.56s
# 951:	learn: 0.5123812	total: 30.3s	remaining: 1.53s
# 952:	learn: 0.5123264	total: 30.4s	remaining: 1.5s
# 953:	learn: 0.5123112	total: 30.4s	remaining: 1.47s
# 954:	learn: 0.5122872	total: 30.4s	remaining: 1.43s
# 955:	learn: 0.5122375	total: 30.5s	remaining: 1.4s
# 956:	learn: 0.5121670	total: 30.5s	remaining: 1.37s
# 957:	learn: 0.5121379	total: 30.5s	remaining: 1.34s
# 958:	learn: 0.5120937	total: 30.5s	remaining: 1.3s
# 959:	learn: 0.5120503	total: 30.6s	remaining: 1.27s
# 960:	learn: 0.5120406	total: 30.6s	remaining: 1.24s
# 961:	learn: 0.5119888	total: 30.6s	remaining: 1.21s
# 962:	learn: 0.5119651	total: 30.6s	remaining: 1.18s
# 963:	learn: 0.5119512	total: 30.7s	remaining: 1.15s
# 964:	learn: 0.5118981	total: 30.7s	remaining: 1.11s
# 965:	learn: 0.5118474	total: 30.7s	remaining: 1.08s
# 966:	learn: 0.5117918	total: 30.7s	remaining: 1.05s
# 967:	learn: 0.5117368	total: 30.8s	remaining: 1.02s
# 968:	learn: 0.5116682	total: 30.8s	remaining: 985ms
# 969:	learn: 0.5116275	total: 30.8s	remaining: 953ms
# 970:	learn: 0.5116126	total: 30.9s	remaining: 922ms
# 971:	learn: 0.5115751	total: 30.9s	remaining: 890ms
# 972:	learn: 0.5115428	total: 30.9s	remaining: 858ms
# 973:	learn: 0.5115146	total: 30.9s	remaining: 826ms
# 974:	learn: 0.5114365	total: 31s	remaining: 794ms
# 975:	learn: 0.5113841	total: 31s	remaining: 762ms
# 976:	learn: 0.5113617	total: 31s	remaining: 730ms
# 977:	learn: 0.5113270	total: 31.1s	remaining: 699ms
# 978:	learn: 0.5112625	total: 31.1s	remaining: 668ms
# 979:	learn: 0.5112407	total: 31.2s	remaining: 636ms
# 980:	learn: 0.5112177	total: 31.2s	remaining: 605ms
# 981:	learn: 0.5112149	total: 31.2s	remaining: 573ms
# 982:	learn: 0.5111739	total: 31.3s	remaining: 541ms
# 983:	learn: 0.5111098	total: 31.3s	remaining: 509ms
# 984:	learn: 0.5110644	total: 31.3s	remaining: 477ms
# 985:	learn: 0.5110291	total: 31.4s	remaining: 446ms
# 986:	learn: 0.5110039	total: 31.4s	remaining: 414ms
# 987:	learn: 0.5109854	total: 31.4s	remaining: 382ms
# 988:	learn: 0.5109575	total: 31.5s	remaining: 350ms
# 989:	learn: 0.5109216	total: 31.5s	remaining: 318ms
# 990:	learn: 0.5109015	total: 31.5s	remaining: 286ms
# 991:	learn: 0.5108294	total: 31.5s	remaining: 254ms
# 992:	learn: 0.5108051	total: 31.6s	remaining: 222ms
# 993:	learn: 0.5107639	total: 31.6s	remaining: 191ms
# 994:	learn: 0.5107204	total: 31.6s	remaining: 159ms
# 995:	learn: 0.5106391	total: 31.6s	remaining: 127ms
# 996:	learn: 0.5106174	total: 31.7s	remaining: 95.3ms
# 997:	learn: 0.5105817	total: 31.7s	remaining: 63.5ms
# 998:	learn: 0.5105664	total: 31.7s	remaining: 31.8ms
# 999:	learn: 0.5105306	total: 31.8s	remaining: 0us

# %%
model.get_params()
# Out:
# {'learning_rate': 0.099,
#  'depth': 5,
#  'l2_leaf_reg': 5,
#  'loss_function': 'RMSE',
#  'verbose': True}

# %%
y_pred_train = model.predict(column_transformer.transform(x_train))
y_pred_test = model.predict(column_transformer.transform(x_test))

print('train MAE: \t', mean_absolute_error(y_pred_train, y_train))

if submit == 2 or submit == 3:
    print('test MAE: \t', mean_absolute_error(y_pred_test, y_test))
# Out:
# train MAE: 	 0.2978317149790738

# %%
y_pred_test = y_scaler.inverse_transform(y_pred_test)

# %%
# Отправка в Kaggle
if submit == 1:
    result = sample_submission.copy()
    result['demand'] = y_pred_test
    result.to_csv('result_{0}.csv'.format('catboost'), index=False)
    print('Generating .csv file .... READY')
# Out:
# Generating .csv file .... READY

# %% [markdown]
# ___
# ___
# # `Описание`

# %% [markdown]
# При первых сабмитах мы пользовались только следующими исходными признаками:
#
# - `period_dt`
# - `location_id`
# - `product_id`
# - `PROMO1_FLAG`
# - `PROMO2_FLAG`
# - `PRICE_REGULAR`
# - `PRICE_AFTER_DISC`
# - `NUM_CONSULTANT`
# - `AUTORIZATION_FLAG`
#
# В последних 6-ти из них были заполнены пропуски. Признак `period_dt` был удален, а из него вычленили `day, month, year`.
#
# После разделения признаков на числовые и категориальные, первые прошли через `StandardScaler`, а вторые - через `OneHotEncoder`.
#
# Были испробованы разные ML-модели, запускались при параметрах по умолчанию. Лучший результат получился при использовании `CatBoost`.

# %%
from IPython.display import Image
#from IPython.core.display import HTML 
Image(
    url= "https://2.downloader.disk.yandex.ru/preview/aca23d4b4f2f83c0f2fef9c368f202e0e18a0f973c4278f04ab2db2014dc4c34/inf/hIglPA1UvTlbC50rheaquA0ZLPKDd3SEPbT7RSxrRDKeArNZWQeI62pB5hYCYgUYlMqYFqnIlz_AY-2XrXO_CA%3D%3D?uid=334642788&filename=%231.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=1903x929",
    width=600,
    height=300)
# Out:
# <img src="https://2.downloader.disk.yandex.ru/preview/aca23d4b4f2f83c0f2fef9c368f202e0e18a0f973c4278f04ab2db2014dc4c34/inf/hIglPA1UvTlbC50rheaquA0ZLPKDd3SEPbT7RSxrRDKeArNZWQeI62pB5hYCYgUYlMqYFqnIlz_AY-2XrXO_CA%3D%3D?uid=334642788&filename=%231.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=1903x929" width="600" height="300"/>

# %% [markdown]
# ___
# Потом захотелось изучить, что лежит в таблицах `product` и `location`. Там по-видимому лежат признаки соответствующих товаров и магазинов.
#
# Что было сделано как для таблицы `product`, так и для `location`:
# - `срез таблицы по встречающимся в исходных данных товарам / магазинам (уменьшили число строк)`
#
#
# - `просмотр числа уникальных значений в каждом столбце таблицы`
#
#
# - `срез таблицы по вырожденным столбцам, которые либо повторяют друг друга, либо имеют слишком неравномерное распределение уникальных значений с точки зрения частоты их встречаемости`
#
# При использовании новых полученных признаков (они категориальные, разумеется)  получились неоднозначеные результаты. Добавление признаков из `location` только ухудшало качество, а признаки из `product` - улучшали.
#
# Также была предпринята попытка срезать признаки по критерию их важности. Во всех тех сабмитах (на картинке ниже), где это использовалось - качество ухудшалось.

# %%
from IPython.display import Image
#from IPython.core.display import HTML 
Image(
    url= "https://2.downloader.disk.yandex.ru/preview/1316877a7a76ec5ff0ef1d1964e0d172e447dfaa7f161090a245affa28494067/inf/b6WL01SB6o30ii5u6MHLFQ0ZLPKDd3SEPbT7RSxrRDKAM2cWwif7xd_X_kLLxONM9Ai8i6z99-I84clhHRbYPg%3D%3D?uid=334642788&filename=%232.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=941x919",
    width=600,
    height=300)
# Out:
# <img src="https://2.downloader.disk.yandex.ru/preview/1316877a7a76ec5ff0ef1d1964e0d172e447dfaa7f161090a245affa28494067/inf/b6WL01SB6o30ii5u6MHLFQ0ZLPKDd3SEPbT7RSxrRDKAM2cWwif7xd_X_kLLxONM9Ai8i6z99-I84clhHRbYPg%3D%3D?uid=334642788&filename=%232.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=941x919" width="600" height="300"/>

# %% [markdown]
# ___
# Были испробованы `lag-features`, но они не улучшили качество, а наоборот.

# %%
from IPython.display import Image
#from IPython.core.display import HTML 
Image(
    url= "https://4.downloader.disk.yandex.ru/preview/b32fa7b51446e052517ddaeaa3527c4c4c807599d16a458d45a0ee74215bf5b8/inf/I5ztsqC3-8U_DCz5KdOsvQ0ZLPKDd3SEPbT7RSxrRDLl-aprY7dgAIApRZQFGk0elZ6MpGK2lLasC9MLZLSM0w%3D%3D?uid=334642788&filename=%233.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=880x919",
    width=600,
    height=300)
# Out:
# <img src="https://4.downloader.disk.yandex.ru/preview/b32fa7b51446e052517ddaeaa3527c4c4c807599d16a458d45a0ee74215bf5b8/inf/I5ztsqC3-8U_DCz5KdOsvQ0ZLPKDd3SEPbT7RSxrRDLl-aprY7dgAIApRZQFGk0elZ6MpGK2lLasC9MLZLSM0w%3D%3D?uid=334642788&filename=%233.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=880x919" width="600" height="300"/>

# %% [markdown]
# ___
# Далее были попытки настроить параметры `CatBoost`, чтобы улучшить свой лучший результат. Этого удалось добиться уменьшив допустимую глубину дереревьев с 6-ти, которая была установлена по умолчанию, до 5-ти.
#
# Изменение метрики (с `RMSE` на `MAE`) и увеличение числа итераций не дали положительного результата.

# %%
from IPython.display import Image
#from IPython.core.display import HTML 
Image(
    url= "https://2.downloader.disk.yandex.ru/preview/af1915403166ea76799d292cd74f3e95d49e3de9289f62065e99f33bb72c1226/inf/tY3Bh0Bv87_AAy2aHJvkjg0ZLPKDd3SEPbT7RSxrRDKn4jJPo7jmZy2_JRSuXgIROsJNbcm0zkxESfOIo9oRjg%3D%3D?uid=334642788&filename=%234.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=880x919",
    width=600,
    height=300)
# Out:
# <img src="https://2.downloader.disk.yandex.ru/preview/af1915403166ea76799d292cd74f3e95d49e3de9289f62065e99f33bb72c1226/inf/tY3Bh0Bv87_AAy2aHJvkjg0ZLPKDd3SEPbT7RSxrRDKn4jJPo7jmZy2_JRSuXgIROsJNbcm0zkxESfOIo9oRjg%3D%3D?uid=334642788&filename=%234.png&disposition=inline&hash=&limit=0&content_type=image%2Fpng&owner_uid=334642788&tknv=v2&size=880x919" width="600" height="300"/>

# %% [markdown]
# ___
# ___
